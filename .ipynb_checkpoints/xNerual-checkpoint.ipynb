# %%
import numpy as np
from IPython.display import Image

# %% [markdown]
# Before we start programming, let's stop for a moment and prepare a basic roadmap. Our goal is to create a program capable of creating a densely connected neural network with the specified architecture (number and size of layers and appropriate activation function). An example of such a network is presented in Figure 1. Above all, we must be able to our network and make predictions using it.
#
# ![Roadmap](./supporting_visualizations/blueprint.gif)
#
# <b>Figure 2.</b> Neural network blueprint
#
# Diagram above shows what operations will have to be performed during the training of our neural network. It also shows how many parameters we will have to update and read at different stages of a single iteration. Building the right data structure and skillfully managing its state is the most difficult part of our task.

# %% [markdown]
# ## Network architecture

# %% [markdown]
# ![Network architecture](./supporting_visualizations/nn_architecture.png)
#
# <b>Figure 1.</b> Example of dense neural network architecture

# %%
NN_ARCHITECTURE = [
    {"input_dim": 2, "output_dim": 25, "activation": "relu"},
    {"input_dim": 25, "output_dim": 1, "activation": "sigmoid"},
]

# %% [markdown]
# ![Parameters sizes](./supporting_visualizations/params_sizes.png)
#
# <b>Figure 3.</b> Dimensions of weight matrix W and bias vector b for layer l.
#
# Let's start with by initiating weight matrix W and bias vector b for each layer. In Figure 3 I have prepared a small cheatsheet, which will help us to asign the appropriate dimensions for these coefficients. Superscript [l] denotes the index of the current layer (counted from 1). I assumed that the information describing the NN architecture will be delivered to our program in the form of list. Each item in the list is a dictionary describing the basic parameters of a single network layer: input_dim - the size of the signal vector supplied as an input for the layer, output_dim - the size of the activation vector obtained at the output of the layer and activation - the activation function to be used inside the layer.

# %%
def init_layers(nn_architecture, seed = 99):
    # random seed initiation
    np.random.seed(seed)
    # number of layers in our neural network
    number_of_layers = len(nn_architecture)
    # parameters storage initiation
    params_values = {}
    
    # iteration over network layers
    for idx, layer in enumerate(nn_architecture):
        # we number network layers from 1
        layer_idx = idx + 1
        
        # extracting the number of units in layers
        layer_input_size = layer["input_dim"]
        layer_output_size = layer["output_dim"]
        
        # initiating the values of the W matrix
        # and vector b for subsequent layers
        params_values['W' + str(layer_idx)] = np.random.randn(
            layer_output_size, layer_input_size) * 0.1
        params_values['b' + str(layer_idx)] = np.random.randn(
            layer_output_size, 1) * 0.1
        
    return params_values

# %%
def sigmoid(Z):
    return 1/(1+np.exp(-Z))

def relu(Z):
    return np.maximum(0,Z)

def sigmoid_backward(dA, Z):
    sig = sigmoid(Z)
    return dA * sig * (1 - sig)

def relu_backward(dA, Z):
    dZ = np.array(dA, copy = True)
    dZ[Z <= 0] = 0;
    return dZ;

# %%
def single_layer_forward_propagation(A_prev, W_curr, b_curr, activation="relu"):
    # calculation of the input value for the activation function
    Z_curr = np.dot(W_curr, A_prev) + b_curr
    
    # selection of activation function
    if activation is "relu":
        activation_func = relu
    elif activation is "sigmoid":
        activation_func = sigmoid
    else:
        raise Exception('Non-supported activation function')
        
    # return of calculated activation A and the intermediate Z matrix
    return activation_func(Z_curr), Z_curr
# Out:
# <>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:8: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:8: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-9-d3e2bf7974c7>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if activation is "relu":
# <ipython-input-9-d3e2bf7974c7>:8: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif activation is "sigmoid":

# %%
def full_forward_propagation(X, params_values, nn_architecture):
    # creating a temporary memory to store the information needed for a backward step
    memory = {}
    # X vector is the activation for layer 0 
    A_curr = X
    
    # iteration over network layers
    for idx, layer in enumerate(nn_architecture):
        # we number network layers from 1
        layer_idx = idx + 1
        # transfer the activation from the previous iteration
        A_prev = A_curr
        
        # extraction of the activation function for the current layer
        activ_function_curr = layer["activation"]
        # extraction of W for the current layer
        W_curr = params_values["W" + str(layer_idx)]
        # extraction of b for the current layer
        b_curr = params_values["b" + str(layer_idx)]
        # calculation of activation for the current layer
        A_curr, Z_curr = single_layer_forward_propagation(A_prev, W_curr, b_curr, activ_function_curr)
        
        # saving calculated values in the memory
        memory["A" + str(idx)] = A_prev
        memory["Z" + str(layer_idx)] = Z_curr
       
    # return of prediction vector and a dictionary containing intermediate values
    return A_curr, memory

# %% [markdown]
# In order to monitor our progress and make sure that we are moving in desired direction, we should routinely calculate the value of the loss function. "Generally speaking, the loss function is designed to show how far we are from the 'ideal' solution." It is selected according to the problem we plan to solve, and frameworks such as Keras have many options to choose from. Because I am planning to test our NN for the classification of points between two classes, I decided to use binary crossentropy, which is defined by the following formulas. In order to give us more information on how our neural network is coping with the task, I have also decided to implement a function that will calculate accuracy for us.
#
# ![Cost Function](./supporting_visualizations/cost_function.gif)

# %%
def get_cost_value(Y_hat, Y):
    # number of examples
    m = Y_hat.shape[1]
    # calculation of the cost according to the formula
    cost = -1 / m * (np.dot(Y, np.log(Y_hat).T) + np.dot(1 - Y, np.log(1 - Y_hat).T))
    return np.squeeze(cost)

# %%
# an auxiliary function that converts probability into class
def convert_prob_into_class(probs):
    probs_ = np.copy(probs)
    probs_[probs_ > 0.5] = 1
    probs_[probs_ <= 0.5] = 0
    return probs_

def get_accuracy_value(Y_hat, Y):
    Y_hat_ = convert_prob_into_class(Y_hat)
    return (Y_hat_ == Y).all(axis=0).mean()

# %% [markdown]
# Sadly, backward propagation is regarded by many inexperienced deep learning enthusiasts as algorithm that is intimidating and difficult to understand. The combination of differential calculus and linear algebra very often deters people who do not have a solid mathematical training.
#
# Often people confuse backward propaganda with gradient descent, but in fact these are two separate matters. The purpose of the first one is to calculate the gradient effectively, whereas the second one is to use the calculated gradient to optimize. In NN, we calculate the gradient of the cost function (discussed earlier) in respect to parameters, but backpropagation can be used to calculate derivatives of any function. The essence of this algorithm is the recursive use of a chain rule known from differential calculus - calculate a derivative of functions created by assembling other functions, whose derivatives we already know. This process - for one network layer - is described by the following formulas. Unfortunately, due to the fact that this article focuses mainly on practical implementation, I'll omit the derivation. Looking at the formulas, it becomes obvious why we decided to remember the values of the A and Z matrices for intermediate layers in a forward step.
#
# $$\boldsymbol{dW}^{[l]} = \frac{\partial L }{\partial \boldsymbol{W}^{[l]}} = \frac{1}{m} \boldsymbol{dZ}^{[l]} \boldsymbol{A}^{[l-1] T}$$
#
# $$\boldsymbol{db}^{[l]} = \frac{\partial L }{\partial \boldsymbol{b}^{[l]}} = \frac{1}{m} \sum_{i = 1}^{m} \boldsymbol{dZ}^{[l](i)}$$
#
# $$\boldsymbol{dA}^{[l-1]} = \frac{\partial L }{\partial \boldsymbol{A}^{[l-1]}} = \boldsymbol{W}^{[l] T} \boldsymbol{dZ}^{[l]}$$
#
# $$\boldsymbol{dZ}^{[l]} = \boldsymbol{dA}^{[l]} * g'(\boldsymbol{Z}^{[l]})$$

# %%
def single_layer_backward_propagation(dA_curr, W_curr, b_curr, Z_curr, A_prev, activation="relu"):
    # number of examples
    m = A_prev.shape[1]
    
    # selection of activation function
    if activation is "relu":
        backward_activation_func = relu_backward
    elif activation is "sigmoid":
        backward_activation_func = sigmoid_backward
    else:
        raise Exception('Non-supported activation function')
    
    # calculation of the activation function derivative
    dZ_curr = backward_activation_func(dA_curr, Z_curr)
    
    # derivative of the matrix W
    dW_curr = np.dot(dZ_curr, A_prev.T) / m
    # derivative of the vector b
    db_curr = np.sum(dZ_curr, axis=1, keepdims=True) / m
    # derivative of the matrix A_prev
    dA_prev = np.dot(W_curr.T, dZ_curr)

    return dA_prev, dW_curr, db_curr
# Out:
# <>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:8: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:8: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-13-0a7b214a3e1f>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if activation is "relu":
# <ipython-input-13-0a7b214a3e1f>:8: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif activation is "sigmoid":

# %%
def full_backward_propagation(Y_hat, Y, memory, params_values, nn_architecture):
    grads_values = {}
    
    # number of examples
    m = Y.shape[1]
    # a hack ensuring the same shape of the prediction vector and labels vector
    Y = Y.reshape(Y_hat.shape)
    
    # initiation of gradient descent algorithm
    dA_prev = - (np.divide(Y, Y_hat) - np.divide(1 - Y, 1 - Y_hat));
    
    for layer_idx_prev, layer in reversed(list(enumerate(nn_architecture))):
        # we number network layers from 1
        layer_idx_curr = layer_idx_prev + 1
        # extraction of the activation function for the current layer
        activ_function_curr = layer["activation"]
        
        dA_curr = dA_prev
        
        A_prev = memory["A" + str(layer_idx_prev)]
        Z_curr = memory["Z" + str(layer_idx_curr)]
        
        W_curr = params_values["W" + str(layer_idx_curr)]
        b_curr = params_values["b" + str(layer_idx_curr)]
        
        dA_prev, dW_curr, db_curr = single_layer_backward_propagation(
            dA_curr, W_curr, b_curr, Z_curr, A_prev, activ_function_curr)
        
        grads_values["dW" + str(layer_idx_curr)] = dW_curr
        grads_values["db" + str(layer_idx_curr)] = db_curr
    
    return grads_values

# %%
def train(X, Y, nn_architecture, epochs, learning_rate, verbose=False, callback=None):
    # initiation of neural net parameters
    params_values = init_layers(nn_architecture, 2)
    # initiation of lists storing the history 
    # of metrics calculated during the learning process 
    cost_history = []
    accuracy_history = []
    
    # performing calculations for subsequent iterations
    for i in range(epochs):
        # step forward
        Y_hat, cashe = full_forward_propagation(X, params_values, nn_architecture)
        
        # calculating metrics and saving them in history
        cost = get_cost_value(Y_hat, Y)
        cost_history.append(cost)
        accuracy = get_accuracy_value(Y_hat, Y)
        accuracy_history.append(accuracy)
        
        # step backward - calculating gradient
        grads_values = full_backward_propagation(Y_hat, Y, cashe, params_values, nn_architecture)
        # updating model state
        params_values = update(params_values, grads_values, nn_architecture, learning_rate)
        
        if(i % 50 == 0):
            if(verbose):
                print("Iteration: {:05} - cost: {:.5f} - accuracy: {:.5f}".format(i, cost, accuracy))
            if(callback is not None):
                callback(i, params_values)
            
    return params_values

# %%
import os
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
sns.set_style("whitegrid")

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
from keras import regularizers

from sklearn.metrics import accuracy_score

# %%
# number of samples in the data set
N_SAMPLES = 1000
# ratio between training and test sets
TEST_SIZE = 0.1
X, y = make_moons(n_samples = N_SAMPLES, noise=0.2, random_state=100)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=42)
X.shape
y.shape

# the function making up the graph of a dataset
def make_plot(X, y, plot_name, file_name=None, XX=None, YY=None, preds=None, dark=False):
    if (dark):
        plt.style.use('dark_background')
    else:
        sns.set_style("whitegrid")
    plt.figure(figsize=(16,12))
    axes = plt.gca()
    axes.set(xlabel="$X_1$", ylabel="$X_2$")
    plt.title(plot_name, fontsize=30)
    plt.subplots_adjust(left=0.20)
    plt.subplots_adjust(right=0.80)
    if(XX is not None and YY is not None and preds is not None):
        plt.contourf(XX, YY, preds.reshape(XX.shape), 25, alpha = 1, cmap=cm.Spectral)
        plt.contour(XX, YY, preds.reshape(XX.shape), levels=[.5], cmap="Greys", vmin=0, vmax=.6)
    plt.scatter(X[:, 0], X[:, 1], c=y.ravel(), s=40, cmap=plt.cm.Spectral, edgecolors='black')
    if(file_name):
        plt.savefig(file_name)
        plt.close()
        
make_plot(X, y, "Dataset")

# %%
# Training
params_values = train(np.transpose(X_train), np.transpose(y_train.reshape((y_train.shape[0], 1))), NN_ARCHITECTURE, 100000, 0.001,verbose=True)
#print(params_values)
# Out:
# Iteration: 00000 - cost: 0.68341 - accuracy: 0.50444
# Iteration: 00050 - cost: 0.68224 - accuracy: 0.50444
# Iteration: 00100 - cost: 0.68106 - accuracy: 0.50444
# Iteration: 00150 - cost: 0.67989 - accuracy: 0.50444
# Iteration: 00200 - cost: 0.67871 - accuracy: 0.50444
# Iteration: 00250 - cost: 0.67753 - accuracy: 0.50444
# Iteration: 00300 - cost: 0.67635 - accuracy: 0.50778
# Iteration: 00350 - cost: 0.67517 - accuracy: 0.51333
# Iteration: 00400 - cost: 0.67399 - accuracy: 0.52111
# Iteration: 00450 - cost: 0.67281 - accuracy: 0.53111
# Iteration: 00500 - cost: 0.67162 - accuracy: 0.55333
# Iteration: 00550 - cost: 0.67043 - accuracy: 0.58111
# Iteration: 00600 - cost: 0.66923 - accuracy: 0.60333
# Iteration: 00650 - cost: 0.66805 - accuracy: 0.62111
# Iteration: 00700 - cost: 0.66686 - accuracy: 0.64667
# Iteration: 00750 - cost: 0.66567 - accuracy: 0.67222
# Iteration: 00800 - cost: 0.66447 - accuracy: 0.69111
# Iteration: 00850 - cost: 0.66328 - accuracy: 0.70667
# Iteration: 00900 - cost: 0.66209 - accuracy: 0.72444
# Iteration: 00950 - cost: 0.66089 - accuracy: 0.74000
# Iteration: 01000 - cost: 0.65970 - accuracy: 0.74889
# Iteration: 01050 - cost: 0.65850 - accuracy: 0.75667
# Iteration: 01100 - cost: 0.65729 - accuracy: 0.76778
# Iteration: 01150 - cost: 0.65607 - accuracy: 0.77111
# Iteration: 01200 - cost: 0.65485 - accuracy: 0.77889
# Iteration: 01250 - cost: 0.65361 - accuracy: 0.78000
# Iteration: 01300 - cost: 0.65237 - accuracy: 0.79000
# Iteration: 01350 - cost: 0.65112 - accuracy: 0.79556
# Iteration: 01400 - cost: 0.64985 - accuracy: 0.79778
# Iteration: 01450 - cost: 0.64858 - accuracy: 0.80000
# Iteration: 01500 - cost: 0.64729 - accuracy: 0.80222
# Iteration: 01550 - cost: 0.64600 - accuracy: 0.80556
# Iteration: 01600 - cost: 0.64469 - accuracy: 0.80889
# Iteration: 01650 - cost: 0.64337 - accuracy: 0.81111
# Iteration: 01700 - cost: 0.64204 - accuracy: 0.80778
# Iteration: 01750 - cost: 0.64069 - accuracy: 0.80778
# Iteration: 01800 - cost: 0.63933 - accuracy: 0.80444
# Iteration: 01850 - cost: 0.63796 - accuracy: 0.80556
# Iteration: 01900 - cost: 0.63658 - accuracy: 0.80667
# Iteration: 01950 - cost: 0.63518 - accuracy: 0.80667
# Iteration: 02000 - cost: 0.63377 - accuracy: 0.80667
# Iteration: 02050 - cost: 0.63235 - accuracy: 0.80889
# Iteration: 02100 - cost: 0.63091 - accuracy: 0.81333
# Iteration: 02150 - cost: 0.62946 - accuracy: 0.81556
# Iteration: 02200 - cost: 0.62800 - accuracy: 0.81444
# Iteration: 02250 - cost: 0.62652 - accuracy: 0.81556
# Iteration: 02300 - cost: 0.62503 - accuracy: 0.81667
# Iteration: 02350 - cost: 0.62352 - accuracy: 0.81556
# Iteration: 02400 - cost: 0.62200 - accuracy: 0.81556
# Iteration: 02450 - cost: 0.62047 - accuracy: 0.81444
# Iteration: 02500 - cost: 0.61892 - accuracy: 0.81556
# Iteration: 02550 - cost: 0.61736 - accuracy: 0.81333
# Iteration: 02600 - cost: 0.61579 - accuracy: 0.81333
# Iteration: 02650 - cost: 0.61420 - accuracy: 0.81333
# Iteration: 02700 - cost: 0.61260 - accuracy: 0.81333
# Iteration: 02750 - cost: 0.61099 - accuracy: 0.81333
# Iteration: 02800 - cost: 0.60936 - accuracy: 0.81444
# Iteration: 02850 - cost: 0.60772 - accuracy: 0.81444
# Iteration: 02900 - cost: 0.60607 - accuracy: 0.81444
# Iteration: 02950 - cost: 0.60439 - accuracy: 0.81000
# Iteration: 03000 - cost: 0.60271 - accuracy: 0.81000
# Iteration: 03050 - cost: 0.60101 - accuracy: 0.81000
# Iteration: 03100 - cost: 0.59929 - accuracy: 0.81000
# Iteration: 03150 - cost: 0.59756 - accuracy: 0.81111
# Iteration: 03200 - cost: 0.59581 - accuracy: 0.81111
# Iteration: 03250 - cost: 0.59405 - accuracy: 0.81000
# Iteration: 03300 - cost: 0.59228 - accuracy: 0.81222
# Iteration: 03350 - cost: 0.59049 - accuracy: 0.81333
# Iteration: 03400 - cost: 0.58869 - accuracy: 0.81444
# Iteration: 03450 - cost: 0.58688 - accuracy: 0.81556
# Iteration: 03500 - cost: 0.58505 - accuracy: 0.81667
# Iteration: 03550 - cost: 0.58320 - accuracy: 0.81667
# Iteration: 03600 - cost: 0.58134 - accuracy: 0.81778
# Iteration: 03650 - cost: 0.57947 - accuracy: 0.81889
# Iteration: 03700 - cost: 0.57758 - accuracy: 0.81889
# Iteration: 03750 - cost: 0.57568 - accuracy: 0.82000
# Iteration: 03800 - cost: 0.57377 - accuracy: 0.82000
# Iteration: 03850 - cost: 0.57185 - accuracy: 0.82000
# Iteration: 03900 - cost: 0.56992 - accuracy: 0.82111
# Iteration: 03950 - cost: 0.56799 - accuracy: 0.82000
# Iteration: 04000 - cost: 0.56604 - accuracy: 0.81667
# Iteration: 04050 - cost: 0.56409 - accuracy: 0.81778
# Iteration: 04100 - cost: 0.56212 - accuracy: 0.81778
# Iteration: 04150 - cost: 0.56015 - accuracy: 0.81778
# Iteration: 04200 - cost: 0.55817 - accuracy: 0.81778
# Iteration: 04250 - cost: 0.55618 - accuracy: 0.81667
# Iteration: 04300 - cost: 0.55418 - accuracy: 0.81667
# Iteration: 04350 - cost: 0.55217 - accuracy: 0.81778
# Iteration: 04400 - cost: 0.55016 - accuracy: 0.81889
# Iteration: 04450 - cost: 0.54814 - accuracy: 0.82000
# Iteration: 04500 - cost: 0.54611 - accuracy: 0.82111
# Iteration: 04550 - cost: 0.54408 - accuracy: 0.82222
# Iteration: 04600 - cost: 0.54205 - accuracy: 0.82222
# Iteration: 04650 - cost: 0.54001 - accuracy: 0.82222
# Iteration: 04700 - cost: 0.53797 - accuracy: 0.82222
# Iteration: 04750 - cost: 0.53592 - accuracy: 0.82333
# Iteration: 04800 - cost: 0.53387 - accuracy: 0.82444
# Iteration: 04850 - cost: 0.53181 - accuracy: 0.82444
# Iteration: 04900 - cost: 0.52976 - accuracy: 0.82444
# Iteration: 04950 - cost: 0.52770 - accuracy: 0.82333
# Iteration: 05000 - cost: 0.52564 - accuracy: 0.82444
# Iteration: 05050 - cost: 0.52359 - accuracy: 0.82556
# Iteration: 05100 - cost: 0.52153 - accuracy: 0.82556
# Iteration: 05150 - cost: 0.51948 - accuracy: 0.82556
# Iteration: 05200 - cost: 0.51742 - accuracy: 0.82667
# Iteration: 05250 - cost: 0.51537 - accuracy: 0.82667
# Iteration: 05300 - cost: 0.51333 - accuracy: 0.82778
# Iteration: 05350 - cost: 0.51128 - accuracy: 0.82667
# Iteration: 05400 - cost: 0.50924 - accuracy: 0.82667
# Iteration: 05450 - cost: 0.50720 - accuracy: 0.82667
# Iteration: 05500 - cost: 0.50515 - accuracy: 0.82667
# Iteration: 05550 - cost: 0.50311 - accuracy: 0.82667
# Iteration: 05600 - cost: 0.50108 - accuracy: 0.82667
# Iteration: 05650 - cost: 0.49905 - accuracy: 0.82667
# Iteration: 05700 - cost: 0.49702 - accuracy: 0.82889
# Iteration: 05750 - cost: 0.49500 - accuracy: 0.82889
# Iteration: 05800 - cost: 0.49299 - accuracy: 0.82889
# Iteration: 05850 - cost: 0.49098 - accuracy: 0.82889
# Iteration: 05900 - cost: 0.48898 - accuracy: 0.82889
# Iteration: 05950 - cost: 0.48699 - accuracy: 0.82889
# Iteration: 06000 - cost: 0.48500 - accuracy: 0.82778
# Iteration: 06050 - cost: 0.48302 - accuracy: 0.82778
# Iteration: 06100 - cost: 0.48105 - accuracy: 0.82778
# Iteration: 06150 - cost: 0.47909 - accuracy: 0.82667
# Iteration: 06200 - cost: 0.47713 - accuracy: 0.82889
# Iteration: 06250 - cost: 0.47519 - accuracy: 0.82778
# Iteration: 06300 - cost: 0.47325 - accuracy: 0.82778
# Iteration: 06350 - cost: 0.47133 - accuracy: 0.83000
# Iteration: 06400 - cost: 0.46943 - accuracy: 0.82889
# Iteration: 06450 - cost: 0.46753 - accuracy: 0.82889
# Iteration: 06500 - cost: 0.46566 - accuracy: 0.83000
# Iteration: 06550 - cost: 0.46380 - accuracy: 0.83000
# Iteration: 06600 - cost: 0.46195 - accuracy: 0.83000
# Iteration: 06650 - cost: 0.46012 - accuracy: 0.83000
# Iteration: 06700 - cost: 0.45830 - accuracy: 0.82889
# Iteration: 06750 - cost: 0.45651 - accuracy: 0.82889
# Iteration: 06800 - cost: 0.45472 - accuracy: 0.82889
# Iteration: 06850 - cost: 0.45295 - accuracy: 0.82889
# Iteration: 06900 - cost: 0.45119 - accuracy: 0.82889
# Iteration: 06950 - cost: 0.44945 - accuracy: 0.82889
# Iteration: 07000 - cost: 0.44772 - accuracy: 0.82889
# Iteration: 07050 - cost: 0.44601 - accuracy: 0.82889
# Iteration: 07100 - cost: 0.44432 - accuracy: 0.82889
# Iteration: 07150 - cost: 0.44264 - accuracy: 0.82889
# Iteration: 07200 - cost: 0.44097 - accuracy: 0.82889
# Iteration: 07250 - cost: 0.43932 - accuracy: 0.82889
# Iteration: 07300 - cost: 0.43768 - accuracy: 0.82889
# Iteration: 07350 - cost: 0.43606 - accuracy: 0.82889
# Iteration: 07400 - cost: 0.43446 - accuracy: 0.82889
# Iteration: 07450 - cost: 0.43287 - accuracy: 0.83000
# Iteration: 07500 - cost: 0.43130 - accuracy: 0.83111
# Iteration: 07550 - cost: 0.42974 - accuracy: 0.83111
# Iteration: 07600 - cost: 0.42820 - accuracy: 0.83000
# Iteration: 07650 - cost: 0.42668 - accuracy: 0.83000
# Iteration: 07700 - cost: 0.42517 - accuracy: 0.83000
# Iteration: 07750 - cost: 0.42368 - accuracy: 0.83000
# Iteration: 07800 - cost: 0.42220 - accuracy: 0.83111
# Iteration: 07850 - cost: 0.42074 - accuracy: 0.83111
# Iteration: 07900 - cost: 0.41929 - accuracy: 0.83111
# Iteration: 07950 - cost: 0.41786 - accuracy: 0.83111
# Iteration: 08000 - cost: 0.41645 - accuracy: 0.83111
# Iteration: 08050 - cost: 0.41505 - accuracy: 0.83222
# Iteration: 08100 - cost: 0.41366 - accuracy: 0.83333
# Iteration: 08150 - cost: 0.41229 - accuracy: 0.83333
# Iteration: 08200 - cost: 0.41094 - accuracy: 0.83333
# Iteration: 08250 - cost: 0.40960 - accuracy: 0.83333
# Iteration: 08300 - cost: 0.40827 - accuracy: 0.83333
# Iteration: 08350 - cost: 0.40696 - accuracy: 0.83333
# Iteration: 08400 - cost: 0.40566 - accuracy: 0.83333
# Iteration: 08450 - cost: 0.40438 - accuracy: 0.83333
# Iteration: 08500 - cost: 0.40311 - accuracy: 0.83444
# Iteration: 08550 - cost: 0.40186 - accuracy: 0.83444
# Iteration: 08600 - cost: 0.40062 - accuracy: 0.83444
# Iteration: 08650 - cost: 0.39939 - accuracy: 0.83444
# Iteration: 08700 - cost: 0.39818 - accuracy: 0.83444
# Iteration: 08750 - cost: 0.39698 - accuracy: 0.83444
# Iteration: 08800 - cost: 0.39580 - accuracy: 0.83667
# Iteration: 08850 - cost: 0.39463 - accuracy: 0.83778
# Iteration: 08900 - cost: 0.39347 - accuracy: 0.83778
# Iteration: 08950 - cost: 0.39233 - accuracy: 0.83778
# Iteration: 09000 - cost: 0.39120 - accuracy: 0.83778
# Iteration: 09050 - cost: 0.39009 - accuracy: 0.83778
# Iteration: 09100 - cost: 0.38899 - accuracy: 0.83778
# Iteration: 09150 - cost: 0.38790 - accuracy: 0.83778
# Iteration: 09200 - cost: 0.38682 - accuracy: 0.83778
# Iteration: 09250 - cost: 0.38576 - accuracy: 0.83778
# Iteration: 09300 - cost: 0.38471 - accuracy: 0.83778
# Iteration: 09350 - cost: 0.38368 - accuracy: 0.83778
# Iteration: 09400 - cost: 0.38265 - accuracy: 0.83778
# Iteration: 09450 - cost: 0.38164 - accuracy: 0.83778
# Iteration: 09500 - cost: 0.38064 - accuracy: 0.84111
# Iteration: 09550 - cost: 0.37965 - accuracy: 0.84111
# Iteration: 09600 - cost: 0.37867 - accuracy: 0.84111
# Iteration: 09650 - cost: 0.37771 - accuracy: 0.84111
# Iteration: 09700 - cost: 0.37675 - accuracy: 0.84111
# Iteration: 09750 - cost: 0.37581 - accuracy: 0.84111
# Iteration: 09800 - cost: 0.37488 - accuracy: 0.84222
# Iteration: 09850 - cost: 0.37396 - accuracy: 0.84222
# Iteration: 09900 - cost: 0.37305 - accuracy: 0.84222
# Iteration: 09950 - cost: 0.37215 - accuracy: 0.84222
# Iteration: 10000 - cost: 0.37126 - accuracy: 0.84111
# Iteration: 10050 - cost: 0.37038 - accuracy: 0.84111
# Iteration: 10100 - cost: 0.36951 - accuracy: 0.84111
# Iteration: 10150 - cost: 0.36865 - accuracy: 0.84111
# Iteration: 10200 - cost: 0.36780 - accuracy: 0.84222
# Iteration: 10250 - cost: 0.36696 - accuracy: 0.84222
# Iteration: 10300 - cost: 0.36613 - accuracy: 0.84333
# Iteration: 10350 - cost: 0.36530 - accuracy: 0.84333
# Iteration: 10400 - cost: 0.36449 - accuracy: 0.84333
# Iteration: 10450 - cost: 0.36369 - accuracy: 0.84444
# Iteration: 10500 - cost: 0.36289 - accuracy: 0.84556
# Iteration: 10550 - cost: 0.36211 - accuracy: 0.84556
# Iteration: 10600 - cost: 0.36133 - accuracy: 0.84556
# Iteration: 10650 - cost: 0.36056 - accuracy: 0.84556
# Iteration: 10700 - cost: 0.35980 - accuracy: 0.84556
# Iteration: 10750 - cost: 0.35905 - accuracy: 0.84556
# Iteration: 10800 - cost: 0.35831 - accuracy: 0.84556
# Iteration: 10850 - cost: 0.35757 - accuracy: 0.84667
# Iteration: 10900 - cost: 0.35685 - accuracy: 0.84667
# Iteration: 10950 - cost: 0.35613 - accuracy: 0.84778
# Iteration: 11000 - cost: 0.35542 - accuracy: 0.84778
# Iteration: 11050 - cost: 0.35472 - accuracy: 0.84889
# Iteration: 11100 - cost: 0.35402 - accuracy: 0.84889
# Iteration: 11150 - cost: 0.35333 - accuracy: 0.84889
# Iteration: 11200 - cost: 0.35265 - accuracy: 0.84889
# Iteration: 11250 - cost: 0.35197 - accuracy: 0.84889
# Iteration: 11300 - cost: 0.35131 - accuracy: 0.84889
# Iteration: 11350 - cost: 0.35065 - accuracy: 0.84889
# Iteration: 11400 - cost: 0.34999 - accuracy: 0.84889
# Iteration: 11450 - cost: 0.34935 - accuracy: 0.84889
# Iteration: 11500 - cost: 0.34871 - accuracy: 0.84889
# Iteration: 11550 - cost: 0.34808 - accuracy: 0.84889
# Iteration: 11600 - cost: 0.34745 - accuracy: 0.84889
# Iteration: 11650 - cost: 0.34683 - accuracy: 0.84889
# Iteration: 11700 - cost: 0.34622 - accuracy: 0.84889
# Iteration: 11750 - cost: 0.34561 - accuracy: 0.84889
# Iteration: 11800 - cost: 0.34501 - accuracy: 0.85000
# Iteration: 11850 - cost: 0.34441 - accuracy: 0.85000
# Iteration: 11900 - cost: 0.34383 - accuracy: 0.85000
# Iteration: 11950 - cost: 0.34324 - accuracy: 0.85000
# Iteration: 12000 - cost: 0.34267 - accuracy: 0.85000
# Iteration: 12050 - cost: 0.34209 - accuracy: 0.85000
# Iteration: 12100 - cost: 0.34153 - accuracy: 0.85000
# Iteration: 12150 - cost: 0.34097 - accuracy: 0.85000
# Iteration: 12200 - cost: 0.34041 - accuracy: 0.85000
# Iteration: 12250 - cost: 0.33987 - accuracy: 0.85000
# Iteration: 12300 - cost: 0.33932 - accuracy: 0.85111
# Iteration: 12350 - cost: 0.33879 - accuracy: 0.85111
# Iteration: 12400 - cost: 0.33825 - accuracy: 0.85222
# Iteration: 12450 - cost: 0.33773 - accuracy: 0.85222
# Iteration: 12500 - cost: 0.33720 - accuracy: 0.85222
# Iteration: 12550 - cost: 0.33669 - accuracy: 0.85333
# Iteration: 12600 - cost: 0.33617 - accuracy: 0.85444
# Iteration: 12650 - cost: 0.33567 - accuracy: 0.85444
# Iteration: 12700 - cost: 0.33517 - accuracy: 0.85444
# Iteration: 12750 - cost: 0.33467 - accuracy: 0.85444
# Iteration: 12800 - cost: 0.33418 - accuracy: 0.85444
# Iteration: 12850 - cost: 0.33369 - accuracy: 0.85444
# Iteration: 12900 - cost: 0.33321 - accuracy: 0.85444
# Iteration: 12950 - cost: 0.33273 - accuracy: 0.85444
# Iteration: 13000 - cost: 0.33225 - accuracy: 0.85444
# Iteration: 13050 - cost: 0.33178 - accuracy: 0.85444
# Iteration: 13100 - cost: 0.33132 - accuracy: 0.85444
# Iteration: 13150 - cost: 0.33086 - accuracy: 0.85444
# Iteration: 13200 - cost: 0.33040 - accuracy: 0.85444
# Iteration: 13250 - cost: 0.32995 - accuracy: 0.85444
# Iteration: 13300 - cost: 0.32950 - accuracy: 0.85556
# Iteration: 13350 - cost: 0.32906 - accuracy: 0.85667
# Iteration: 13400 - cost: 0.32862 - accuracy: 0.85667
# Iteration: 13450 - cost: 0.32818 - accuracy: 0.85667
# Iteration: 13500 - cost: 0.32775 - accuracy: 0.85667
# Iteration: 13550 - cost: 0.32732 - accuracy: 0.85667
# Iteration: 13600 - cost: 0.32690 - accuracy: 0.85667
# Iteration: 13650 - cost: 0.32648 - accuracy: 0.85667
# Iteration: 13700 - cost: 0.32606 - accuracy: 0.85667
# Iteration: 13750 - cost: 0.32565 - accuracy: 0.85667
# Iteration: 13800 - cost: 0.32524 - accuracy: 0.85778
# Iteration: 13850 - cost: 0.32484 - accuracy: 0.85778
# Iteration: 13900 - cost: 0.32444 - accuracy: 0.85778
# Iteration: 13950 - cost: 0.32404 - accuracy: 0.85778
# Iteration: 14000 - cost: 0.32364 - accuracy: 0.85778
# Iteration: 14050 - cost: 0.32325 - accuracy: 0.85778
# Iteration: 14100 - cost: 0.32287 - accuracy: 0.85778
# Iteration: 14150 - cost: 0.32248 - accuracy: 0.85778
# Iteration: 14200 - cost: 0.32210 - accuracy: 0.85778
# Iteration: 14250 - cost: 0.32172 - accuracy: 0.85778
# Iteration: 14300 - cost: 0.32135 - accuracy: 0.85778
# Iteration: 14350 - cost: 0.32098 - accuracy: 0.85778
# Iteration: 14400 - cost: 0.32061 - accuracy: 0.85889
# Iteration: 14450 - cost: 0.32025 - accuracy: 0.85889
# Iteration: 14500 - cost: 0.31989 - accuracy: 0.85889
# Iteration: 14550 - cost: 0.31953 - accuracy: 0.85889
# Iteration: 14600 - cost: 0.31918 - accuracy: 0.85889
# Iteration: 14650 - cost: 0.31882 - accuracy: 0.85889
# Iteration: 14700 - cost: 0.31848 - accuracy: 0.85889
# Iteration: 14750 - cost: 0.31813 - accuracy: 0.86000
# Iteration: 14800 - cost: 0.31779 - accuracy: 0.86111
# Iteration: 14850 - cost: 0.31745 - accuracy: 0.86222
# Iteration: 14900 - cost: 0.31711 - accuracy: 0.86222
# Iteration: 14950 - cost: 0.31678 - accuracy: 0.86222
# Iteration: 15000 - cost: 0.31644 - accuracy: 0.86222
# Iteration: 15050 - cost: 0.31611 - accuracy: 0.86222
# Iteration: 15100 - cost: 0.31579 - accuracy: 0.86222
# Iteration: 15150 - cost: 0.31546 - accuracy: 0.86222
# Iteration: 15200 - cost: 0.31514 - accuracy: 0.86222
# Iteration: 15250 - cost: 0.31482 - accuracy: 0.86222
# Iteration: 15300 - cost: 0.31451 - accuracy: 0.86222
# Iteration: 15350 - cost: 0.31420 - accuracy: 0.86222
# Iteration: 15400 - cost: 0.31389 - accuracy: 0.86222
# Iteration: 15450 - cost: 0.31358 - accuracy: 0.86222
# Iteration: 15500 - cost: 0.31327 - accuracy: 0.86222
# Iteration: 15550 - cost: 0.31297 - accuracy: 0.86222
# Iteration: 15600 - cost: 0.31267 - accuracy: 0.86222
# Iteration: 15650 - cost: 0.31237 - accuracy: 0.86222
# Iteration: 15700 - cost: 0.31207 - accuracy: 0.86222
# Iteration: 15750 - cost: 0.31178 - accuracy: 0.86222
# Iteration: 15800 - cost: 0.31149 - accuracy: 0.86222
# Iteration: 15850 - cost: 0.31120 - accuracy: 0.86333
# Iteration: 15900 - cost: 0.31092 - accuracy: 0.86333
# Iteration: 15950 - cost: 0.31063 - accuracy: 0.86333
# Iteration: 16000 - cost: 0.31035 - accuracy: 0.86333
# Iteration: 16050 - cost: 0.31007 - accuracy: 0.86333
# Iteration: 16100 - cost: 0.30979 - accuracy: 0.86333
# Iteration: 16150 - cost: 0.30952 - accuracy: 0.86333
# Iteration: 16200 - cost: 0.30925 - accuracy: 0.86333
# Iteration: 16250 - cost: 0.30898 - accuracy: 0.86333
# Iteration: 16300 - cost: 0.30871 - accuracy: 0.86333
# Iteration: 16350 - cost: 0.30844 - accuracy: 0.86444
# Iteration: 16400 - cost: 0.30818 - accuracy: 0.86444
# Iteration: 16450 - cost: 0.30792 - accuracy: 0.86444
# Iteration: 16500 - cost: 0.30766 - accuracy: 0.86556
# Iteration: 16550 - cost: 0.30740 - accuracy: 0.86667
# Iteration: 16600 - cost: 0.30714 - accuracy: 0.86667
# Iteration: 16650 - cost: 0.30689 - accuracy: 0.86667
# Iteration: 16700 - cost: 0.30664 - accuracy: 0.86667
# Iteration: 16750 - cost: 0.30639 - accuracy: 0.86667
# Iteration: 16800 - cost: 0.30614 - accuracy: 0.86667
# Iteration: 16850 - cost: 0.30589 - accuracy: 0.86667
# Iteration: 16900 - cost: 0.30565 - accuracy: 0.86667
# Iteration: 16950 - cost: 0.30541 - accuracy: 0.86667
# Iteration: 17000 - cost: 0.30517 - accuracy: 0.86667
# Iteration: 17050 - cost: 0.30493 - accuracy: 0.86667
# Iteration: 17100 - cost: 0.30469 - accuracy: 0.86667
# Iteration: 17150 - cost: 0.30446 - accuracy: 0.86667
# Iteration: 17200 - cost: 0.30423 - accuracy: 0.86778
# Iteration: 17250 - cost: 0.30399 - accuracy: 0.86778
# Iteration: 17300 - cost: 0.30377 - accuracy: 0.86778
# Iteration: 17350 - cost: 0.30354 - accuracy: 0.86889
# Iteration: 17400 - cost: 0.30331 - accuracy: 0.86889
# Iteration: 17450 - cost: 0.30309 - accuracy: 0.86889
# Iteration: 17500 - cost: 0.30287 - accuracy: 0.86889
# Iteration: 17550 - cost: 0.30265 - accuracy: 0.86889
# Iteration: 17600 - cost: 0.30243 - accuracy: 0.86889
# Iteration: 17650 - cost: 0.30221 - accuracy: 0.86889
# Iteration: 17700 - cost: 0.30200 - accuracy: 0.86889
# Iteration: 17750 - cost: 0.30178 - accuracy: 0.86889
# Iteration: 17800 - cost: 0.30157 - accuracy: 0.86889
# Iteration: 17850 - cost: 0.30136 - accuracy: 0.86889
# Iteration: 17900 - cost: 0.30116 - accuracy: 0.86889
# Iteration: 17950 - cost: 0.30095 - accuracy: 0.86889
# Iteration: 18000 - cost: 0.30075 - accuracy: 0.86889
# Iteration: 18050 - cost: 0.30054 - accuracy: 0.86889
# Iteration: 18100 - cost: 0.30034 - accuracy: 0.86889
# Iteration: 18150 - cost: 0.30014 - accuracy: 0.86889
# Iteration: 18200 - cost: 0.29994 - accuracy: 0.86889
# Iteration: 18250 - cost: 0.29975 - accuracy: 0.86889
# Iteration: 18300 - cost: 0.29955 - accuracy: 0.86889
# Iteration: 18350 - cost: 0.29936 - accuracy: 0.86889
# Iteration: 18400 - cost: 0.29916 - accuracy: 0.86889
# Iteration: 18450 - cost: 0.29897 - accuracy: 0.86889
# Iteration: 18500 - cost: 0.29878 - accuracy: 0.86889
# Iteration: 18550 - cost: 0.29860 - accuracy: 0.86889
# Iteration: 18600 - cost: 0.29841 - accuracy: 0.86889
# Iteration: 18650 - cost: 0.29822 - accuracy: 0.86889
# Iteration: 18700 - cost: 0.29804 - accuracy: 0.86889
# Iteration: 18750 - cost: 0.29786 - accuracy: 0.86889
# Iteration: 18800 - cost: 0.29768 - accuracy: 0.86889
# Iteration: 18850 - cost: 0.29750 - accuracy: 0.86889
# Iteration: 18900 - cost: 0.29732 - accuracy: 0.86889
# Iteration: 18950 - cost: 0.29714 - accuracy: 0.86889
# Iteration: 19000 - cost: 0.29697 - accuracy: 0.86889
# Iteration: 19050 - cost: 0.29679 - accuracy: 0.86889
# Iteration: 19100 - cost: 0.29662 - accuracy: 0.86889
# Iteration: 19150 - cost: 0.29645 - accuracy: 0.86889
# Iteration: 19200 - cost: 0.29628 - accuracy: 0.86889
# Iteration: 19250 - cost: 0.29611 - accuracy: 0.87000
# Iteration: 19300 - cost: 0.29594 - accuracy: 0.87000
# Iteration: 19350 - cost: 0.29578 - accuracy: 0.87000
# Iteration: 19400 - cost: 0.29561 - accuracy: 0.87000
# Iteration: 19450 - cost: 0.29545 - accuracy: 0.87000
# Iteration: 19500 - cost: 0.29529 - accuracy: 0.87000
# Iteration: 19550 - cost: 0.29513 - accuracy: 0.87000
# Iteration: 19600 - cost: 0.29497 - accuracy: 0.87000
# Iteration: 19650 - cost: 0.29481 - accuracy: 0.87000
# Iteration: 19700 - cost: 0.29465 - accuracy: 0.87000
# Iteration: 19750 - cost: 0.29449 - accuracy: 0.87000
# Iteration: 19800 - cost: 0.29434 - accuracy: 0.87111
# Iteration: 19850 - cost: 0.29418 - accuracy: 0.87111
# Iteration: 19900 - cost: 0.29403 - accuracy: 0.87111
# Iteration: 19950 - cost: 0.29388 - accuracy: 0.87111
# Iteration: 20000 - cost: 0.29373 - accuracy: 0.87222
# Iteration: 20050 - cost: 0.29358 - accuracy: 0.87222
# Iteration: 20100 - cost: 0.29343 - accuracy: 0.87222
# Iteration: 20150 - cost: 0.29329 - accuracy: 0.87222
# Iteration: 20200 - cost: 0.29314 - accuracy: 0.87222
# Iteration: 20250 - cost: 0.29299 - accuracy: 0.87222
# Iteration: 20300 - cost: 0.29285 - accuracy: 0.87222
# Iteration: 20350 - cost: 0.29271 - accuracy: 0.87222
# Iteration: 20400 - cost: 0.29257 - accuracy: 0.87222
# Iteration: 20450 - cost: 0.29242 - accuracy: 0.87222
# Iteration: 20500 - cost: 0.29228 - accuracy: 0.87222
# Iteration: 20550 - cost: 0.29215 - accuracy: 0.87222
# Iteration: 20600 - cost: 0.29201 - accuracy: 0.87222
# Iteration: 20650 - cost: 0.29187 - accuracy: 0.87222
# Iteration: 20700 - cost: 0.29174 - accuracy: 0.87222
# Iteration: 20750 - cost: 0.29160 - accuracy: 0.87222
# Iteration: 20800 - cost: 0.29147 - accuracy: 0.87222
# Iteration: 20850 - cost: 0.29134 - accuracy: 0.87222
# Iteration: 20900 - cost: 0.29121 - accuracy: 0.87222
# Iteration: 20950 - cost: 0.29108 - accuracy: 0.87222
# Iteration: 21000 - cost: 0.29095 - accuracy: 0.87222
# Iteration: 21050 - cost: 0.29082 - accuracy: 0.87222
# Iteration: 21100 - cost: 0.29069 - accuracy: 0.87222
# Iteration: 21150 - cost: 0.29056 - accuracy: 0.87222
# Iteration: 21200 - cost: 0.29044 - accuracy: 0.87222
# Iteration: 21250 - cost: 0.29031 - accuracy: 0.87222
# Iteration: 21300 - cost: 0.29019 - accuracy: 0.87222
# Iteration: 21350 - cost: 0.29007 - accuracy: 0.87222
# Iteration: 21400 - cost: 0.28995 - accuracy: 0.87222
# Iteration: 21450 - cost: 0.28982 - accuracy: 0.87222
# Iteration: 21500 - cost: 0.28970 - accuracy: 0.87333
# Iteration: 21550 - cost: 0.28959 - accuracy: 0.87333
# Iteration: 21600 - cost: 0.28947 - accuracy: 0.87333
# Iteration: 21650 - cost: 0.28935 - accuracy: 0.87333
# Iteration: 21700 - cost: 0.28923 - accuracy: 0.87333
# Iteration: 21750 - cost: 0.28912 - accuracy: 0.87333
# Iteration: 21800 - cost: 0.28900 - accuracy: 0.87333
# Iteration: 21850 - cost: 0.28889 - accuracy: 0.87333
# Iteration: 21900 - cost: 0.28878 - accuracy: 0.87444
# Iteration: 21950 - cost: 0.28866 - accuracy: 0.87444
# Iteration: 22000 - cost: 0.28855 - accuracy: 0.87444
# Iteration: 22050 - cost: 0.28844 - accuracy: 0.87444
# Iteration: 22100 - cost: 0.28833 - accuracy: 0.87444
# Iteration: 22150 - cost: 0.28822 - accuracy: 0.87444
# Iteration: 22200 - cost: 0.28812 - accuracy: 0.87444
# Iteration: 22250 - cost: 0.28801 - accuracy: 0.87444
# Iteration: 22300 - cost: 0.28790 - accuracy: 0.87444
# Iteration: 22350 - cost: 0.28780 - accuracy: 0.87444
# Iteration: 22400 - cost: 0.28769 - accuracy: 0.87444
# Iteration: 22450 - cost: 0.28759 - accuracy: 0.87444
# Iteration: 22500 - cost: 0.28748 - accuracy: 0.87333
# Iteration: 22550 - cost: 0.28738 - accuracy: 0.87444
# Iteration: 22600 - cost: 0.28728 - accuracy: 0.87444
# Iteration: 22650 - cost: 0.28718 - accuracy: 0.87444
# Iteration: 22700 - cost: 0.28708 - accuracy: 0.87444
# Iteration: 22750 - cost: 0.28698 - accuracy: 0.87444
# Iteration: 22800 - cost: 0.28688 - accuracy: 0.87444
# Iteration: 22850 - cost: 0.28678 - accuracy: 0.87444
# Iteration: 22900 - cost: 0.28668 - accuracy: 0.87444
# Iteration: 22950 - cost: 0.28658 - accuracy: 0.87444
# Iteration: 23000 - cost: 0.28649 - accuracy: 0.87444
# Iteration: 23050 - cost: 0.28639 - accuracy: 0.87444
# Iteration: 23100 - cost: 0.28630 - accuracy: 0.87444
# Iteration: 23150 - cost: 0.28620 - accuracy: 0.87444
# Iteration: 23200 - cost: 0.28611 - accuracy: 0.87444
# Iteration: 23250 - cost: 0.28601 - accuracy: 0.87444
# Iteration: 23300 - cost: 0.28592 - accuracy: 0.87444
# Iteration: 23350 - cost: 0.28583 - accuracy: 0.87444
# Iteration: 23400 - cost: 0.28574 - accuracy: 0.87444
# Iteration: 23450 - cost: 0.28565 - accuracy: 0.87556
# Iteration: 23500 - cost: 0.28556 - accuracy: 0.87556
# Iteration: 23550 - cost: 0.28547 - accuracy: 0.87556
# Iteration: 23600 - cost: 0.28538 - accuracy: 0.87556
# Iteration: 23650 - cost: 0.28529 - accuracy: 0.87556
# Iteration: 23700 - cost: 0.28521 - accuracy: 0.87556
# Iteration: 23750 - cost: 0.28512 - accuracy: 0.87667
# Iteration: 23800 - cost: 0.28503 - accuracy: 0.87667
# Iteration: 23850 - cost: 0.28495 - accuracy: 0.87667
# Iteration: 23900 - cost: 0.28486 - accuracy: 0.87778
# Iteration: 23950 - cost: 0.28478 - accuracy: 0.87778
# Iteration: 24000 - cost: 0.28469 - accuracy: 0.87778
# Iteration: 24050 - cost: 0.28461 - accuracy: 0.87778
# Iteration: 24100 - cost: 0.28453 - accuracy: 0.87778
# Iteration: 24150 - cost: 0.28445 - accuracy: 0.87778
# Iteration: 24200 - cost: 0.28436 - accuracy: 0.87778
# Iteration: 24250 - cost: 0.28428 - accuracy: 0.87778
# Iteration: 24300 - cost: 0.28420 - accuracy: 0.87889
# Iteration: 24350 - cost: 0.28412 - accuracy: 0.87889
# Iteration: 24400 - cost: 0.28404 - accuracy: 0.87889
# Iteration: 24450 - cost: 0.28397 - accuracy: 0.87889
# Iteration: 24500 - cost: 0.28389 - accuracy: 0.87889
# Iteration: 24550 - cost: 0.28381 - accuracy: 0.87889
# Iteration: 24600 - cost: 0.28373 - accuracy: 0.87889
# Iteration: 24650 - cost: 0.28366 - accuracy: 0.87889
# Iteration: 24700 - cost: 0.28358 - accuracy: 0.87889
# Iteration: 24750 - cost: 0.28350 - accuracy: 0.87889
# Iteration: 24800 - cost: 0.28343 - accuracy: 0.87889
# Iteration: 24850 - cost: 0.28335 - accuracy: 0.87889
# Iteration: 24900 - cost: 0.28328 - accuracy: 0.87889
# Iteration: 24950 - cost: 0.28321 - accuracy: 0.87889
# Iteration: 25000 - cost: 0.28313 - accuracy: 0.87889
# Iteration: 25050 - cost: 0.28306 - accuracy: 0.87889
# Iteration: 25100 - cost: 0.28299 - accuracy: 0.87889
# Iteration: 25150 - cost: 0.28292 - accuracy: 0.88000
# Iteration: 25200 - cost: 0.28285 - accuracy: 0.88000
# Iteration: 25250 - cost: 0.28278 - accuracy: 0.88000
# Iteration: 25300 - cost: 0.28271 - accuracy: 0.88000
# Iteration: 25350 - cost: 0.28264 - accuracy: 0.88000
# Iteration: 25400 - cost: 0.28257 - accuracy: 0.87889
# Iteration: 25450 - cost: 0.28250 - accuracy: 0.87889
# Iteration: 25500 - cost: 0.28243 - accuracy: 0.87889
# Iteration: 25550 - cost: 0.28236 - accuracy: 0.87889
# Iteration: 25600 - cost: 0.28229 - accuracy: 0.87889
# Iteration: 25650 - cost: 0.28223 - accuracy: 0.87889
# Iteration: 25700 - cost: 0.28216 - accuracy: 0.87889
# Iteration: 25750 - cost: 0.28209 - accuracy: 0.87889
# Iteration: 25800 - cost: 0.28203 - accuracy: 0.87889
# Iteration: 25850 - cost: 0.28196 - accuracy: 0.87889
# Iteration: 25900 - cost: 0.28190 - accuracy: 0.87889
# Iteration: 25950 - cost: 0.28183 - accuracy: 0.87889
# Iteration: 26000 - cost: 0.28177 - accuracy: 0.87889
# Iteration: 26050 - cost: 0.28171 - accuracy: 0.87889
# Iteration: 26100 - cost: 0.28164 - accuracy: 0.87889
# Iteration: 26150 - cost: 0.28158 - accuracy: 0.87889
# Iteration: 26200 - cost: 0.28152 - accuracy: 0.87889
# Iteration: 26250 - cost: 0.28146 - accuracy: 0.87889
# Iteration: 26300 - cost: 0.28139 - accuracy: 0.87889
# Iteration: 26350 - cost: 0.28133 - accuracy: 0.87889
# Iteration: 26400 - cost: 0.28127 - accuracy: 0.87889
# Iteration: 26450 - cost: 0.28121 - accuracy: 0.87889
# Iteration: 26500 - cost: 0.28115 - accuracy: 0.87778
# Iteration: 26550 - cost: 0.28109 - accuracy: 0.87778
# Iteration: 26600 - cost: 0.28103 - accuracy: 0.87778
# Iteration: 26650 - cost: 0.28097 - accuracy: 0.87778
# Iteration: 26700 - cost: 0.28092 - accuracy: 0.87778
# Iteration: 26750 - cost: 0.28086 - accuracy: 0.87778
# Iteration: 26800 - cost: 0.28080 - accuracy: 0.87778
# Iteration: 26850 - cost: 0.28074 - accuracy: 0.87778
# Iteration: 26900 - cost: 0.28068 - accuracy: 0.87778
# Iteration: 26950 - cost: 0.28063 - accuracy: 0.87778
# Iteration: 27000 - cost: 0.28057 - accuracy: 0.87778
# Iteration: 27050 - cost: 0.28052 - accuracy: 0.87778
# Iteration: 27100 - cost: 0.28046 - accuracy: 0.87778
# Iteration: 27150 - cost: 0.28040 - accuracy: 0.87778
# Iteration: 27200 - cost: 0.28035 - accuracy: 0.87889
# Iteration: 27250 - cost: 0.28030 - accuracy: 0.87889
# Iteration: 27300 - cost: 0.28024 - accuracy: 0.87778
# Iteration: 27350 - cost: 0.28019 - accuracy: 0.87778
# Iteration: 27400 - cost: 0.28013 - accuracy: 0.87778
# Iteration: 27450 - cost: 0.28008 - accuracy: 0.87778
# Iteration: 27500 - cost: 0.28003 - accuracy: 0.87778
# Iteration: 27550 - cost: 0.27998 - accuracy: 0.87778
# Iteration: 27600 - cost: 0.27993 - accuracy: 0.87778
# Iteration: 27650 - cost: 0.27987 - accuracy: 0.87778
# Iteration: 27700 - cost: 0.27982 - accuracy: 0.87778
# Iteration: 27750 - cost: 0.27977 - accuracy: 0.87778
# Iteration: 27800 - cost: 0.27972 - accuracy: 0.87778
# Iteration: 27850 - cost: 0.27967 - accuracy: 0.87778
# Iteration: 27900 - cost: 0.27962 - accuracy: 0.87778
# Iteration: 27950 - cost: 0.27957 - accuracy: 0.87778
# Iteration: 28000 - cost: 0.27953 - accuracy: 0.87778
# Iteration: 28050 - cost: 0.27948 - accuracy: 0.87778
# Iteration: 28100 - cost: 0.27943 - accuracy: 0.87778
# Iteration: 28150 - cost: 0.27938 - accuracy: 0.87778
# Iteration: 28200 - cost: 0.27933 - accuracy: 0.87778
# Iteration: 28250 - cost: 0.27928 - accuracy: 0.87778
# Iteration: 28300 - cost: 0.27924 - accuracy: 0.87778
# Iteration: 28350 - cost: 0.27919 - accuracy: 0.87778
# Iteration: 28400 - cost: 0.27914 - accuracy: 0.87778
# Iteration: 28450 - cost: 0.27910 - accuracy: 0.87778
# Iteration: 28500 - cost: 0.27905 - accuracy: 0.87778
# Iteration: 28550 - cost: 0.27901 - accuracy: 0.87778
# Iteration: 28600 - cost: 0.27896 - accuracy: 0.87778
# Iteration: 28650 - cost: 0.27892 - accuracy: 0.87778
# Iteration: 28700 - cost: 0.27887 - accuracy: 0.87778
# Iteration: 28750 - cost: 0.27883 - accuracy: 0.87778
# Iteration: 28800 - cost: 0.27878 - accuracy: 0.87778
# Iteration: 28850 - cost: 0.27874 - accuracy: 0.87778
# Iteration: 28900 - cost: 0.27869 - accuracy: 0.87778
# Iteration: 28950 - cost: 0.27865 - accuracy: 0.87778
# Iteration: 29000 - cost: 0.27861 - accuracy: 0.87778
# Iteration: 29050 - cost: 0.27856 - accuracy: 0.87778
# Iteration: 29100 - cost: 0.27852 - accuracy: 0.87778
# Iteration: 29150 - cost: 0.27848 - accuracy: 0.87778
# Iteration: 29200 - cost: 0.27844 - accuracy: 0.87778
# Iteration: 29250 - cost: 0.27839 - accuracy: 0.87778
# Iteration: 29300 - cost: 0.27835 - accuracy: 0.87778
# Iteration: 29350 - cost: 0.27831 - accuracy: 0.87778
# Iteration: 29400 - cost: 0.27827 - accuracy: 0.87778
# Iteration: 29450 - cost: 0.27823 - accuracy: 0.87778
# Iteration: 29500 - cost: 0.27819 - accuracy: 0.87778
# Iteration: 29550 - cost: 0.27815 - accuracy: 0.87778
# Iteration: 29600 - cost: 0.27811 - accuracy: 0.87778
# Iteration: 29650 - cost: 0.27807 - accuracy: 0.87778
# Iteration: 29700 - cost: 0.27803 - accuracy: 0.87778
# Iteration: 29750 - cost: 0.27799 - accuracy: 0.87778
# Iteration: 29800 - cost: 0.27795 - accuracy: 0.87778
# Iteration: 29850 - cost: 0.27791 - accuracy: 0.87778
# Iteration: 29900 - cost: 0.27787 - accuracy: 0.87778
# Iteration: 29950 - cost: 0.27784 - accuracy: 0.87778
# Iteration: 30000 - cost: 0.27780 - accuracy: 0.87778
# Iteration: 30050 - cost: 0.27776 - accuracy: 0.87778
# Iteration: 30100 - cost: 0.27772 - accuracy: 0.87778
# Iteration: 30150 - cost: 0.27768 - accuracy: 0.87778
# Iteration: 30200 - cost: 0.27765 - accuracy: 0.87778
# Iteration: 30250 - cost: 0.27761 - accuracy: 0.87778
# Iteration: 30300 - cost: 0.27757 - accuracy: 0.87778
# Iteration: 30350 - cost: 0.27754 - accuracy: 0.87778
# Iteration: 30400 - cost: 0.27750 - accuracy: 0.87778
# Iteration: 30450 - cost: 0.27746 - accuracy: 0.87778
# Iteration: 30500 - cost: 0.27743 - accuracy: 0.87778
# Iteration: 30550 - cost: 0.27739 - accuracy: 0.87778
# Iteration: 30600 - cost: 0.27736 - accuracy: 0.87778
# Iteration: 30650 - cost: 0.27732 - accuracy: 0.87778
# Iteration: 30700 - cost: 0.27729 - accuracy: 0.87778
# Iteration: 30750 - cost: 0.27725 - accuracy: 0.87778
# Iteration: 30800 - cost: 0.27722 - accuracy: 0.87778
# Iteration: 30850 - cost: 0.27718 - accuracy: 0.87778
# Iteration: 30900 - cost: 0.27715 - accuracy: 0.87778
# Iteration: 30950 - cost: 0.27711 - accuracy: 0.87778
# Iteration: 31000 - cost: 0.27708 - accuracy: 0.87778
# Iteration: 31050 - cost: 0.27705 - accuracy: 0.87778
# Iteration: 31100 - cost: 0.27701 - accuracy: 0.87778
# Iteration: 31150 - cost: 0.27698 - accuracy: 0.87778
# Iteration: 31200 - cost: 0.27695 - accuracy: 0.87778
# Iteration: 31250 - cost: 0.27691 - accuracy: 0.87778
# Iteration: 31300 - cost: 0.27688 - accuracy: 0.87778
# Iteration: 31350 - cost: 0.27685 - accuracy: 0.87778
# Iteration: 31400 - cost: 0.27682 - accuracy: 0.87778
# Iteration: 31450 - cost: 0.27679 - accuracy: 0.87778
# Iteration: 31500 - cost: 0.27675 - accuracy: 0.87778
# Iteration: 31550 - cost: 0.27672 - accuracy: 0.87778
# Iteration: 31600 - cost: 0.27669 - accuracy: 0.87778
# Iteration: 31650 - cost: 0.27666 - accuracy: 0.87778
# Iteration: 31700 - cost: 0.27663 - accuracy: 0.87778
# Iteration: 31750 - cost: 0.27660 - accuracy: 0.87778
# Iteration: 31800 - cost: 0.27657 - accuracy: 0.87778
# Iteration: 31850 - cost: 0.27654 - accuracy: 0.87778
# Iteration: 31900 - cost: 0.27651 - accuracy: 0.87778
# Iteration: 31950 - cost: 0.27647 - accuracy: 0.87778
# Iteration: 32000 - cost: 0.27645 - accuracy: 0.87778
# Iteration: 32050 - cost: 0.27642 - accuracy: 0.87778
# Iteration: 32100 - cost: 0.27639 - accuracy: 0.87778
# Iteration: 32150 - cost: 0.27636 - accuracy: 0.87778
# Iteration: 32200 - cost: 0.27633 - accuracy: 0.87778
# Iteration: 32250 - cost: 0.27630 - accuracy: 0.87778
# Iteration: 32300 - cost: 0.27627 - accuracy: 0.87778
# Iteration: 32350 - cost: 0.27624 - accuracy: 0.87778
# Iteration: 32400 - cost: 0.27621 - accuracy: 0.87778
# Iteration: 32450 - cost: 0.27618 - accuracy: 0.87778
# Iteration: 32500 - cost: 0.27616 - accuracy: 0.87778
# Iteration: 32550 - cost: 0.27613 - accuracy: 0.87778
# Iteration: 32600 - cost: 0.27610 - accuracy: 0.87778
# Iteration: 32650 - cost: 0.27607 - accuracy: 0.87778
# Iteration: 32700 - cost: 0.27604 - accuracy: 0.87778
# Iteration: 32750 - cost: 0.27602 - accuracy: 0.87778
# Iteration: 32800 - cost: 0.27599 - accuracy: 0.87778
# Iteration: 32850 - cost: 0.27596 - accuracy: 0.87778
# Iteration: 32900 - cost: 0.27594 - accuracy: 0.87778
# Iteration: 32950 - cost: 0.27591 - accuracy: 0.87778
# Iteration: 33000 - cost: 0.27588 - accuracy: 0.87778
# Iteration: 33050 - cost: 0.27586 - accuracy: 0.87778
# Iteration: 33100 - cost: 0.27583 - accuracy: 0.87778
# Iteration: 33150 - cost: 0.27580 - accuracy: 0.87778
# Iteration: 33200 - cost: 0.27578 - accuracy: 0.87778
# Iteration: 33250 - cost: 0.27575 - accuracy: 0.87778
# Iteration: 33300 - cost: 0.27573 - accuracy: 0.87778
# Iteration: 33350 - cost: 0.27570 - accuracy: 0.87778
# Iteration: 33400 - cost: 0.27567 - accuracy: 0.87778
# Iteration: 33450 - cost: 0.27565 - accuracy: 0.87778
# Iteration: 33500 - cost: 0.27562 - accuracy: 0.87778
# Iteration: 33550 - cost: 0.27560 - accuracy: 0.87778
# Iteration: 33600 - cost: 0.27557 - accuracy: 0.87778
# Iteration: 33650 - cost: 0.27555 - accuracy: 0.87778
# Iteration: 33700 - cost: 0.27552 - accuracy: 0.87778
# Iteration: 33750 - cost: 0.27550 - accuracy: 0.87778
# Iteration: 33800 - cost: 0.27547 - accuracy: 0.87778
# Iteration: 33850 - cost: 0.27545 - accuracy: 0.87778
# Iteration: 33900 - cost: 0.27543 - accuracy: 0.87778
# Iteration: 33950 - cost: 0.27540 - accuracy: 0.87778
# Iteration: 34000 - cost: 0.27538 - accuracy: 0.87778
# Iteration: 34050 - cost: 0.27535 - accuracy: 0.87778
# Iteration: 34100 - cost: 0.27533 - accuracy: 0.87778
# Iteration: 34150 - cost: 0.27531 - accuracy: 0.87778
# Iteration: 34200 - cost: 0.27528 - accuracy: 0.87778
# Iteration: 34250 - cost: 0.27526 - accuracy: 0.87778
# Iteration: 34300 - cost: 0.27524 - accuracy: 0.87778
# Iteration: 34350 - cost: 0.27521 - accuracy: 0.87778
# Iteration: 34400 - cost: 0.27519 - accuracy: 0.87667
# Iteration: 34450 - cost: 0.27517 - accuracy: 0.87667
# Iteration: 34500 - cost: 0.27514 - accuracy: 0.87667
# Iteration: 34550 - cost: 0.27512 - accuracy: 0.87667
# Iteration: 34600 - cost: 0.27510 - accuracy: 0.87667
# Iteration: 34650 - cost: 0.27508 - accuracy: 0.87667
# Iteration: 34700 - cost: 0.27505 - accuracy: 0.87667
# Iteration: 34750 - cost: 0.27503 - accuracy: 0.87667
# Iteration: 34800 - cost: 0.27501 - accuracy: 0.87667
# Iteration: 34850 - cost: 0.27499 - accuracy: 0.87667
# Iteration: 34900 - cost: 0.27496 - accuracy: 0.87667
# Iteration: 34950 - cost: 0.27494 - accuracy: 0.87667
# Iteration: 35000 - cost: 0.27492 - accuracy: 0.87667
# Iteration: 35050 - cost: 0.27490 - accuracy: 0.87667
# Iteration: 35100 - cost: 0.27488 - accuracy: 0.87667
# Iteration: 35150 - cost: 0.27486 - accuracy: 0.87778
# Iteration: 35200 - cost: 0.27483 - accuracy: 0.87778
# Iteration: 35250 - cost: 0.27481 - accuracy: 0.87778
# Iteration: 35300 - cost: 0.27479 - accuracy: 0.87778
# Iteration: 35350 - cost: 0.27477 - accuracy: 0.87778
# Iteration: 35400 - cost: 0.27475 - accuracy: 0.87778
# Iteration: 35450 - cost: 0.27473 - accuracy: 0.87778
# Iteration: 35500 - cost: 0.27471 - accuracy: 0.87778
# Iteration: 35550 - cost: 0.27469 - accuracy: 0.87778
# Iteration: 35600 - cost: 0.27467 - accuracy: 0.87778
# Iteration: 35650 - cost: 0.27465 - accuracy: 0.87778
# Iteration: 35700 - cost: 0.27463 - accuracy: 0.87778
# Iteration: 35750 - cost: 0.27461 - accuracy: 0.87778
# Iteration: 35800 - cost: 0.27459 - accuracy: 0.88000
# Iteration: 35850 - cost: 0.27457 - accuracy: 0.88000
# Iteration: 35900 - cost: 0.27455 - accuracy: 0.88000
# Iteration: 35950 - cost: 0.27453 - accuracy: 0.88000
# Iteration: 36000 - cost: 0.27451 - accuracy: 0.88000
# Iteration: 36050 - cost: 0.27449 - accuracy: 0.88000
# Iteration: 36100 - cost: 0.27447 - accuracy: 0.88000
# Iteration: 36150 - cost: 0.27445 - accuracy: 0.88000
# Iteration: 36200 - cost: 0.27443 - accuracy: 0.88000
# Iteration: 36250 - cost: 0.27441 - accuracy: 0.88000
# Iteration: 36300 - cost: 0.27439 - accuracy: 0.88000
# Iteration: 36350 - cost: 0.27437 - accuracy: 0.88000
# Iteration: 36400 - cost: 0.27435 - accuracy: 0.88000
# Iteration: 36450 - cost: 0.27433 - accuracy: 0.88000
# Iteration: 36500 - cost: 0.27431 - accuracy: 0.88000
# Iteration: 36550 - cost: 0.27429 - accuracy: 0.88000
# Iteration: 36600 - cost: 0.27428 - accuracy: 0.88000
# Iteration: 36650 - cost: 0.27426 - accuracy: 0.88000
# Iteration: 36700 - cost: 0.27424 - accuracy: 0.88000
# Iteration: 36750 - cost: 0.27422 - accuracy: 0.88000
# Iteration: 36800 - cost: 0.27420 - accuracy: 0.88000
# Iteration: 36850 - cost: 0.27418 - accuracy: 0.88000
# Iteration: 36900 - cost: 0.27416 - accuracy: 0.88000
# Iteration: 36950 - cost: 0.27415 - accuracy: 0.88000
# Iteration: 37000 - cost: 0.27413 - accuracy: 0.88000
# Iteration: 37050 - cost: 0.27411 - accuracy: 0.88000
# Iteration: 37100 - cost: 0.27409 - accuracy: 0.88000
# Iteration: 37150 - cost: 0.27407 - accuracy: 0.88000
# Iteration: 37200 - cost: 0.27406 - accuracy: 0.88000
# Iteration: 37250 - cost: 0.27404 - accuracy: 0.88000
# Iteration: 37300 - cost: 0.27402 - accuracy: 0.88000
# Iteration: 37350 - cost: 0.27400 - accuracy: 0.88000
# Iteration: 37400 - cost: 0.27399 - accuracy: 0.88000
# Iteration: 37450 - cost: 0.27397 - accuracy: 0.88000
# Iteration: 37500 - cost: 0.27395 - accuracy: 0.88000
# Iteration: 37550 - cost: 0.27393 - accuracy: 0.88000
# Iteration: 37600 - cost: 0.27392 - accuracy: 0.88000
# Iteration: 37650 - cost: 0.27390 - accuracy: 0.88000
# Iteration: 37700 - cost: 0.27388 - accuracy: 0.88000
# Iteration: 37750 - cost: 0.27386 - accuracy: 0.88000
# Iteration: 37800 - cost: 0.27385 - accuracy: 0.88000
# Iteration: 37850 - cost: 0.27383 - accuracy: 0.88000
# Iteration: 37900 - cost: 0.27381 - accuracy: 0.88000
# Iteration: 37950 - cost: 0.27380 - accuracy: 0.88000
# Iteration: 38000 - cost: 0.27378 - accuracy: 0.88000
# Iteration: 38050 - cost: 0.27376 - accuracy: 0.88000
# Iteration: 38100 - cost: 0.27375 - accuracy: 0.88000
# Iteration: 38150 - cost: 0.27373 - accuracy: 0.88000
# Iteration: 38200 - cost: 0.27371 - accuracy: 0.88000
# Iteration: 38250 - cost: 0.27370 - accuracy: 0.88000
# Iteration: 38300 - cost: 0.27368 - accuracy: 0.88000
# Iteration: 38350 - cost: 0.27366 - accuracy: 0.88000
# Iteration: 38400 - cost: 0.27365 - accuracy: 0.88000
# Iteration: 38450 - cost: 0.27363 - accuracy: 0.88000
# Iteration: 38500 - cost: 0.27362 - accuracy: 0.88000
# Iteration: 38550 - cost: 0.27360 - accuracy: 0.88000
# Iteration: 38600 - cost: 0.27358 - accuracy: 0.88000
# Iteration: 38650 - cost: 0.27357 - accuracy: 0.88000
# Iteration: 38700 - cost: 0.27355 - accuracy: 0.88000
# Iteration: 38750 - cost: 0.27354 - accuracy: 0.88000
# Iteration: 38800 - cost: 0.27352 - accuracy: 0.88000
# Iteration: 38850 - cost: 0.27350 - accuracy: 0.88000
# Iteration: 38900 - cost: 0.27349 - accuracy: 0.88000
# Iteration: 38950 - cost: 0.27347 - accuracy: 0.88000
# Iteration: 39000 - cost: 0.27346 - accuracy: 0.88000
# Iteration: 39050 - cost: 0.27344 - accuracy: 0.88000
# Iteration: 39100 - cost: 0.27343 - accuracy: 0.88000
# Iteration: 39150 - cost: 0.27341 - accuracy: 0.88000
# Iteration: 39200 - cost: 0.27340 - accuracy: 0.88000
# Iteration: 39250 - cost: 0.27338 - accuracy: 0.88111
# Iteration: 39300 - cost: 0.27337 - accuracy: 0.88111
# Iteration: 39350 - cost: 0.27335 - accuracy: 0.88111
# Iteration: 39400 - cost: 0.27334 - accuracy: 0.88111
# Iteration: 39450 - cost: 0.27332 - accuracy: 0.88111
# Iteration: 39500 - cost: 0.27331 - accuracy: 0.88111
# Iteration: 39550 - cost: 0.27329 - accuracy: 0.88111
# Iteration: 39600 - cost: 0.27328 - accuracy: 0.88111
# Iteration: 39650 - cost: 0.27326 - accuracy: 0.88111
# Iteration: 39700 - cost: 0.27325 - accuracy: 0.88111
# Iteration: 39750 - cost: 0.27323 - accuracy: 0.88111
# Iteration: 39800 - cost: 0.27322 - accuracy: 0.88111
# Iteration: 39850 - cost: 0.27320 - accuracy: 0.88111
# Iteration: 39900 - cost: 0.27319 - accuracy: 0.88111
# Iteration: 39950 - cost: 0.27317 - accuracy: 0.88111
# Iteration: 40000 - cost: 0.27316 - accuracy: 0.88111
# Iteration: 40050 - cost: 0.27315 - accuracy: 0.88111
# Iteration: 40100 - cost: 0.27313 - accuracy: 0.88111
# Iteration: 40150 - cost: 0.27312 - accuracy: 0.88111
# Iteration: 40200 - cost: 0.27310 - accuracy: 0.88111
# Iteration: 40250 - cost: 0.27309 - accuracy: 0.88111
# Iteration: 40300 - cost: 0.27307 - accuracy: 0.88111
# Iteration: 40350 - cost: 0.27306 - accuracy: 0.88111
# Iteration: 40400 - cost: 0.27305 - accuracy: 0.88111
# Iteration: 40450 - cost: 0.27303 - accuracy: 0.88111
# Iteration: 40500 - cost: 0.27302 - accuracy: 0.88111
# Iteration: 40550 - cost: 0.27300 - accuracy: 0.88111
# Iteration: 40600 - cost: 0.27299 - accuracy: 0.88111
# Iteration: 40650 - cost: 0.27298 - accuracy: 0.88111
# Iteration: 40700 - cost: 0.27296 - accuracy: 0.88111
# Iteration: 40750 - cost: 0.27295 - accuracy: 0.88111
# Iteration: 40800 - cost: 0.27294 - accuracy: 0.88111
# Iteration: 40850 - cost: 0.27292 - accuracy: 0.88111
# Iteration: 40900 - cost: 0.27291 - accuracy: 0.88111
# Iteration: 40950 - cost: 0.27289 - accuracy: 0.88111
# Iteration: 41000 - cost: 0.27288 - accuracy: 0.88111
# Iteration: 41050 - cost: 0.27287 - accuracy: 0.88111
# Iteration: 41100 - cost: 0.27285 - accuracy: 0.88111
# Iteration: 41150 - cost: 0.27284 - accuracy: 0.88111
# Iteration: 41200 - cost: 0.27283 - accuracy: 0.88111
# Iteration: 41250 - cost: 0.27281 - accuracy: 0.88111
# Iteration: 41300 - cost: 0.27280 - accuracy: 0.88111
# Iteration: 41350 - cost: 0.27279 - accuracy: 0.88111
# Iteration: 41400 - cost: 0.27277 - accuracy: 0.88111
# Iteration: 41450 - cost: 0.27276 - accuracy: 0.88111
# Iteration: 41500 - cost: 0.27275 - accuracy: 0.88111
# Iteration: 41550 - cost: 0.27273 - accuracy: 0.88111
# Iteration: 41600 - cost: 0.27272 - accuracy: 0.88111
# Iteration: 41650 - cost: 0.27271 - accuracy: 0.88111
# Iteration: 41700 - cost: 0.27269 - accuracy: 0.88111
# Iteration: 41750 - cost: 0.27268 - accuracy: 0.88111
# Iteration: 41800 - cost: 0.27267 - accuracy: 0.88111
# Iteration: 41850 - cost: 0.27266 - accuracy: 0.88111
# Iteration: 41900 - cost: 0.27264 - accuracy: 0.88111
# Iteration: 41950 - cost: 0.27263 - accuracy: 0.88111
# Iteration: 42000 - cost: 0.27262 - accuracy: 0.88111
# Iteration: 42050 - cost: 0.27260 - accuracy: 0.88111
# Iteration: 42100 - cost: 0.27259 - accuracy: 0.88111
# Iteration: 42150 - cost: 0.27258 - accuracy: 0.88111
# Iteration: 42200 - cost: 0.27257 - accuracy: 0.88111
# Iteration: 42250 - cost: 0.27255 - accuracy: 0.88111
# Iteration: 42300 - cost: 0.27254 - accuracy: 0.88111
# Iteration: 42350 - cost: 0.27253 - accuracy: 0.88111
# Iteration: 42400 - cost: 0.27252 - accuracy: 0.88111
# Iteration: 42450 - cost: 0.27250 - accuracy: 0.88111
# Iteration: 42500 - cost: 0.27249 - accuracy: 0.88111
# Iteration: 42550 - cost: 0.27248 - accuracy: 0.88111
# Iteration: 42600 - cost: 0.27247 - accuracy: 0.88111
# Iteration: 42650 - cost: 0.27245 - accuracy: 0.88111
# Iteration: 42700 - cost: 0.27244 - accuracy: 0.88111
# Iteration: 42750 - cost: 0.27243 - accuracy: 0.88111
# Iteration: 42800 - cost: 0.27242 - accuracy: 0.88111
# Iteration: 42850 - cost: 0.27240 - accuracy: 0.88111
# Iteration: 42900 - cost: 0.27239 - accuracy: 0.88111
# Iteration: 42950 - cost: 0.27238 - accuracy: 0.88111
# Iteration: 43000 - cost: 0.27237 - accuracy: 0.88111
# Iteration: 43050 - cost: 0.27236 - accuracy: 0.88111
# Iteration: 43100 - cost: 0.27234 - accuracy: 0.88111
# Iteration: 43150 - cost: 0.27233 - accuracy: 0.88111
# Iteration: 43200 - cost: 0.27232 - accuracy: 0.88111
# Iteration: 43250 - cost: 0.27231 - accuracy: 0.88111
# Iteration: 43300 - cost: 0.27230 - accuracy: 0.88111
# Iteration: 43350 - cost: 0.27228 - accuracy: 0.88111
# Iteration: 43400 - cost: 0.27227 - accuracy: 0.88111
# Iteration: 43450 - cost: 0.27226 - accuracy: 0.88111
# Iteration: 43500 - cost: 0.27225 - accuracy: 0.88111
# Iteration: 43550 - cost: 0.27224 - accuracy: 0.88111
# Iteration: 43600 - cost: 0.27222 - accuracy: 0.88111
# Iteration: 43650 - cost: 0.27221 - accuracy: 0.88111
# Iteration: 43700 - cost: 0.27220 - accuracy: 0.88111
# Iteration: 43750 - cost: 0.27219 - accuracy: 0.88111
# Iteration: 43800 - cost: 0.27218 - accuracy: 0.88111
# Iteration: 43850 - cost: 0.27217 - accuracy: 0.88111
# Iteration: 43900 - cost: 0.27215 - accuracy: 0.88111
# Iteration: 43950 - cost: 0.27214 - accuracy: 0.88111
# Iteration: 44000 - cost: 0.27213 - accuracy: 0.88111
# Iteration: 44050 - cost: 0.27212 - accuracy: 0.88111
# Iteration: 44100 - cost: 0.27211 - accuracy: 0.88111
# Iteration: 44150 - cost: 0.27210 - accuracy: 0.88111
# Iteration: 44200 - cost: 0.27209 - accuracy: 0.88111
# Iteration: 44250 - cost: 0.27207 - accuracy: 0.88111
# Iteration: 44300 - cost: 0.27206 - accuracy: 0.88111
# Iteration: 44350 - cost: 0.27205 - accuracy: 0.88111
# Iteration: 44400 - cost: 0.27204 - accuracy: 0.88111
# Iteration: 44450 - cost: 0.27203 - accuracy: 0.88111
# Iteration: 44500 - cost: 0.27202 - accuracy: 0.88111
# Iteration: 44550 - cost: 0.27201 - accuracy: 0.88111
# Iteration: 44600 - cost: 0.27199 - accuracy: 0.88111
# Iteration: 44650 - cost: 0.27198 - accuracy: 0.88111
# Iteration: 44700 - cost: 0.27197 - accuracy: 0.88111
# Iteration: 44750 - cost: 0.27196 - accuracy: 0.88111
# Iteration: 44800 - cost: 0.27195 - accuracy: 0.88111
# Iteration: 44850 - cost: 0.27194 - accuracy: 0.88111
# Iteration: 44900 - cost: 0.27193 - accuracy: 0.88111
# Iteration: 44950 - cost: 0.27192 - accuracy: 0.88111
# Iteration: 45000 - cost: 0.27190 - accuracy: 0.88111
# Iteration: 45050 - cost: 0.27189 - accuracy: 0.88111
# Iteration: 45100 - cost: 0.27188 - accuracy: 0.88111
# Iteration: 45150 - cost: 0.27187 - accuracy: 0.88111
# Iteration: 45200 - cost: 0.27186 - accuracy: 0.88111
# ...
# Iteration: 84950 - cost: 0.26363 - accuracy: 0.88000
# Iteration: 85000 - cost: 0.26362 - accuracy: 0.88000
# Iteration: 85050 - cost: 0.26361 - accuracy: 0.88000
# Iteration: 85100 - cost: 0.26360 - accuracy: 0.88000
# Iteration: 85150 - cost: 0.26358 - accuracy: 0.88000
# Iteration: 85200 - cost: 0.26357 - accuracy: 0.88000
# Iteration: 85250 - cost: 0.26356 - accuracy: 0.88000
# Iteration: 85300 - cost: 0.26355 - accuracy: 0.88000
# Iteration: 85350 - cost: 0.26354 - accuracy: 0.88000
# Iteration: 85400 - cost: 0.26353 - accuracy: 0.88000
# Iteration: 85450 - cost: 0.26351 - accuracy: 0.88000
# Iteration: 85500 - cost: 0.26350 - accuracy: 0.88000
# Iteration: 85550 - cost: 0.26349 - accuracy: 0.88000
# Iteration: 85600 - cost: 0.26348 - accuracy: 0.88000
# Iteration: 85650 - cost: 0.26347 - accuracy: 0.88000
# Iteration: 85700 - cost: 0.26345 - accuracy: 0.88000
# Iteration: 85750 - cost: 0.26344 - accuracy: 0.88000
# Iteration: 85800 - cost: 0.26343 - accuracy: 0.88000
# Iteration: 85850 - cost: 0.26342 - accuracy: 0.88000
# Iteration: 85900 - cost: 0.26341 - accuracy: 0.88000
# Iteration: 85950 - cost: 0.26340 - accuracy: 0.88000
# Iteration: 86000 - cost: 0.26338 - accuracy: 0.88000
# Iteration: 86050 - cost: 0.26337 - accuracy: 0.88000
# Iteration: 86100 - cost: 0.26336 - accuracy: 0.88000
# Iteration: 86150 - cost: 0.26335 - accuracy: 0.88000
# Iteration: 86200 - cost: 0.26334 - accuracy: 0.88000
# Iteration: 86250 - cost: 0.26332 - accuracy: 0.88000
# Iteration: 86300 - cost: 0.26331 - accuracy: 0.88000
# Iteration: 86350 - cost: 0.26330 - accuracy: 0.88000
# Iteration: 86400 - cost: 0.26329 - accuracy: 0.88000
# Iteration: 86450 - cost: 0.26328 - accuracy: 0.88000
# Iteration: 86500 - cost: 0.26326 - accuracy: 0.88000
# Iteration: 86550 - cost: 0.26325 - accuracy: 0.88000
# Iteration: 86600 - cost: 0.26324 - accuracy: 0.88000
# Iteration: 86650 - cost: 0.26323 - accuracy: 0.88000
# Iteration: 86700 - cost: 0.26322 - accuracy: 0.88000
# Iteration: 86750 - cost: 0.26320 - accuracy: 0.88000
# Iteration: 86800 - cost: 0.26319 - accuracy: 0.88000
# Iteration: 86850 - cost: 0.26318 - accuracy: 0.88000
# Iteration: 86900 - cost: 0.26317 - accuracy: 0.88000
# Iteration: 86950 - cost: 0.26316 - accuracy: 0.88000
# Iteration: 87000 - cost: 0.26314 - accuracy: 0.88000
# Iteration: 87050 - cost: 0.26313 - accuracy: 0.88000
# Iteration: 87100 - cost: 0.26312 - accuracy: 0.88000
# Iteration: 87150 - cost: 0.26311 - accuracy: 0.88000
# Iteration: 87200 - cost: 0.26310 - accuracy: 0.88000
# Iteration: 87250 - cost: 0.26308 - accuracy: 0.88000
# Iteration: 87300 - cost: 0.26307 - accuracy: 0.88000
# Iteration: 87350 - cost: 0.26306 - accuracy: 0.88000
# Iteration: 87400 - cost: 0.26305 - accuracy: 0.88000
# Iteration: 87450 - cost: 0.26304 - accuracy: 0.88000
# Iteration: 87500 - cost: 0.26302 - accuracy: 0.88000
# Iteration: 87550 - cost: 0.26301 - accuracy: 0.88000
# Iteration: 87600 - cost: 0.26300 - accuracy: 0.88000
# Iteration: 87650 - cost: 0.26299 - accuracy: 0.88000
# Iteration: 87700 - cost: 0.26298 - accuracy: 0.88000
# Iteration: 87750 - cost: 0.26296 - accuracy: 0.88000
# Iteration: 87800 - cost: 0.26295 - accuracy: 0.88000
# Iteration: 87850 - cost: 0.26294 - accuracy: 0.88000
# Iteration: 87900 - cost: 0.26293 - accuracy: 0.88000
# Iteration: 87950 - cost: 0.26292 - accuracy: 0.88000
# Iteration: 88000 - cost: 0.26290 - accuracy: 0.88000
# Iteration: 88050 - cost: 0.26289 - accuracy: 0.88000
# Iteration: 88100 - cost: 0.26288 - accuracy: 0.88000
# Iteration: 88150 - cost: 0.26287 - accuracy: 0.88000
# Iteration: 88200 - cost: 0.26286 - accuracy: 0.88000
# Iteration: 88250 - cost: 0.26284 - accuracy: 0.88000
# Iteration: 88300 - cost: 0.26283 - accuracy: 0.88000
# Iteration: 88350 - cost: 0.26282 - accuracy: 0.88000
# Iteration: 88400 - cost: 0.26281 - accuracy: 0.88000
# Iteration: 88450 - cost: 0.26279 - accuracy: 0.88000
# Iteration: 88500 - cost: 0.26278 - accuracy: 0.88000
# Iteration: 88550 - cost: 0.26277 - accuracy: 0.88000
# Iteration: 88600 - cost: 0.26276 - accuracy: 0.88000
# Iteration: 88650 - cost: 0.26275 - accuracy: 0.88000
# Iteration: 88700 - cost: 0.26273 - accuracy: 0.88000
# Iteration: 88750 - cost: 0.26272 - accuracy: 0.88000
# Iteration: 88800 - cost: 0.26271 - accuracy: 0.88000
# Iteration: 88850 - cost: 0.26270 - accuracy: 0.88000
# Iteration: 88900 - cost: 0.26269 - accuracy: 0.88000
# Iteration: 88950 - cost: 0.26267 - accuracy: 0.88000
# Iteration: 89000 - cost: 0.26266 - accuracy: 0.88000
# Iteration: 89050 - cost: 0.26265 - accuracy: 0.88000
# Iteration: 89100 - cost: 0.26264 - accuracy: 0.88000
# Iteration: 89150 - cost: 0.26262 - accuracy: 0.88000
# Iteration: 89200 - cost: 0.26261 - accuracy: 0.88000
# Iteration: 89250 - cost: 0.26260 - accuracy: 0.88000
# Iteration: 89300 - cost: 0.26259 - accuracy: 0.88000
# Iteration: 89350 - cost: 0.26258 - accuracy: 0.88000
# Iteration: 89400 - cost: 0.26256 - accuracy: 0.88000
# Iteration: 89450 - cost: 0.26255 - accuracy: 0.88000
# Iteration: 89500 - cost: 0.26254 - accuracy: 0.88000
# Iteration: 89550 - cost: 0.26253 - accuracy: 0.88000
# Iteration: 89600 - cost: 0.26251 - accuracy: 0.88000
# Iteration: 89650 - cost: 0.26250 - accuracy: 0.88000
# Iteration: 89700 - cost: 0.26249 - accuracy: 0.88000
# Iteration: 89750 - cost: 0.26248 - accuracy: 0.88000
# Iteration: 89800 - cost: 0.26247 - accuracy: 0.88000
# Iteration: 89850 - cost: 0.26245 - accuracy: 0.88000
# Iteration: 89900 - cost: 0.26244 - accuracy: 0.88000
# Iteration: 89950 - cost: 0.26243 - accuracy: 0.88000
# Iteration: 90000 - cost: 0.26242 - accuracy: 0.88000
# Iteration: 90050 - cost: 0.26240 - accuracy: 0.88000
# Iteration: 90100 - cost: 0.26239 - accuracy: 0.88000
# Iteration: 90150 - cost: 0.26238 - accuracy: 0.88000
# Iteration: 90200 - cost: 0.26237 - accuracy: 0.88000
# Iteration: 90250 - cost: 0.26235 - accuracy: 0.88000
# Iteration: 90300 - cost: 0.26234 - accuracy: 0.88000
# Iteration: 90350 - cost: 0.26233 - accuracy: 0.88000
# Iteration: 90400 - cost: 0.26232 - accuracy: 0.88000
# Iteration: 90450 - cost: 0.26231 - accuracy: 0.88000
# Iteration: 90500 - cost: 0.26229 - accuracy: 0.88000
# Iteration: 90550 - cost: 0.26228 - accuracy: 0.88000
# Iteration: 90600 - cost: 0.26227 - accuracy: 0.88000
# Iteration: 90650 - cost: 0.26226 - accuracy: 0.88000
# Iteration: 90700 - cost: 0.26224 - accuracy: 0.88000
# Iteration: 90750 - cost: 0.26223 - accuracy: 0.88000
# Iteration: 90800 - cost: 0.26222 - accuracy: 0.88000
# Iteration: 90850 - cost: 0.26221 - accuracy: 0.88000
# Iteration: 90900 - cost: 0.26219 - accuracy: 0.88000
# Iteration: 90950 - cost: 0.26218 - accuracy: 0.88000
# Iteration: 91000 - cost: 0.26217 - accuracy: 0.88000
# Iteration: 91050 - cost: 0.26216 - accuracy: 0.88000
# Iteration: 91100 - cost: 0.26214 - accuracy: 0.88000
# Iteration: 91150 - cost: 0.26213 - accuracy: 0.88000
# Iteration: 91200 - cost: 0.26212 - accuracy: 0.88000
# Iteration: 91250 - cost: 0.26211 - accuracy: 0.88000
# Iteration: 91300 - cost: 0.26209 - accuracy: 0.88000
# Iteration: 91350 - cost: 0.26208 - accuracy: 0.88000
# Iteration: 91400 - cost: 0.26207 - accuracy: 0.88000
# Iteration: 91450 - cost: 0.26206 - accuracy: 0.88000
# Iteration: 91500 - cost: 0.26205 - accuracy: 0.88000
# Iteration: 91550 - cost: 0.26203 - accuracy: 0.88000
# Iteration: 91600 - cost: 0.26202 - accuracy: 0.88000
# Iteration: 91650 - cost: 0.26201 - accuracy: 0.88000
# Iteration: 91700 - cost: 0.26200 - accuracy: 0.88000
# Iteration: 91750 - cost: 0.26198 - accuracy: 0.88000
# Iteration: 91800 - cost: 0.26197 - accuracy: 0.88000
# Iteration: 91850 - cost: 0.26196 - accuracy: 0.88000
# Iteration: 91900 - cost: 0.26195 - accuracy: 0.88000
# Iteration: 91950 - cost: 0.26193 - accuracy: 0.88000
# Iteration: 92000 - cost: 0.26192 - accuracy: 0.88000
# Iteration: 92050 - cost: 0.26191 - accuracy: 0.88000
# Iteration: 92100 - cost: 0.26190 - accuracy: 0.88000
# Iteration: 92150 - cost: 0.26188 - accuracy: 0.88000
# Iteration: 92200 - cost: 0.26187 - accuracy: 0.88000
# Iteration: 92250 - cost: 0.26186 - accuracy: 0.88000
# Iteration: 92300 - cost: 0.26185 - accuracy: 0.88000
# Iteration: 92350 - cost: 0.26183 - accuracy: 0.88000
# Iteration: 92400 - cost: 0.26182 - accuracy: 0.88000
# Iteration: 92450 - cost: 0.26181 - accuracy: 0.88000
# Iteration: 92500 - cost: 0.26180 - accuracy: 0.88000
# Iteration: 92550 - cost: 0.26178 - accuracy: 0.88000
# Iteration: 92600 - cost: 0.26177 - accuracy: 0.88000
# Iteration: 92650 - cost: 0.26176 - accuracy: 0.88000
# Iteration: 92700 - cost: 0.26175 - accuracy: 0.88000
# Iteration: 92750 - cost: 0.26173 - accuracy: 0.88000
# Iteration: 92800 - cost: 0.26172 - accuracy: 0.88000
# Iteration: 92850 - cost: 0.26171 - accuracy: 0.88000
# Iteration: 92900 - cost: 0.26170 - accuracy: 0.88000
# Iteration: 92950 - cost: 0.26168 - accuracy: 0.88000
# Iteration: 93000 - cost: 0.26167 - accuracy: 0.88000
# Iteration: 93050 - cost: 0.26166 - accuracy: 0.88000
# Iteration: 93100 - cost: 0.26165 - accuracy: 0.88000
# Iteration: 93150 - cost: 0.26163 - accuracy: 0.88000
# Iteration: 93200 - cost: 0.26162 - accuracy: 0.88000
# Iteration: 93250 - cost: 0.26161 - accuracy: 0.88000
# Iteration: 93300 - cost: 0.26160 - accuracy: 0.88000
# Iteration: 93350 - cost: 0.26158 - accuracy: 0.88000
# Iteration: 93400 - cost: 0.26157 - accuracy: 0.88000
# Iteration: 93450 - cost: 0.26156 - accuracy: 0.88000
# Iteration: 93500 - cost: 0.26154 - accuracy: 0.88000
# Iteration: 93550 - cost: 0.26153 - accuracy: 0.88000
# Iteration: 93600 - cost: 0.26152 - accuracy: 0.88000
# Iteration: 93650 - cost: 0.26151 - accuracy: 0.88000
# Iteration: 93700 - cost: 0.26149 - accuracy: 0.88000
# Iteration: 93750 - cost: 0.26148 - accuracy: 0.88000
# Iteration: 93800 - cost: 0.26147 - accuracy: 0.88000
# Iteration: 93850 - cost: 0.26146 - accuracy: 0.88000
# Iteration: 93900 - cost: 0.26144 - accuracy: 0.88000
# Iteration: 93950 - cost: 0.26143 - accuracy: 0.88000
# Iteration: 94000 - cost: 0.26142 - accuracy: 0.88000
# Iteration: 94050 - cost: 0.26141 - accuracy: 0.88000
# Iteration: 94100 - cost: 0.26139 - accuracy: 0.88000
# Iteration: 94150 - cost: 0.26138 - accuracy: 0.88000
# Iteration: 94200 - cost: 0.26137 - accuracy: 0.88000
# Iteration: 94250 - cost: 0.26136 - accuracy: 0.88000
# Iteration: 94300 - cost: 0.26134 - accuracy: 0.88000
# Iteration: 94350 - cost: 0.26133 - accuracy: 0.88000
# Iteration: 94400 - cost: 0.26132 - accuracy: 0.88000
# Iteration: 94450 - cost: 0.26130 - accuracy: 0.88000
# Iteration: 94500 - cost: 0.26129 - accuracy: 0.88000
# Iteration: 94550 - cost: 0.26128 - accuracy: 0.88000
# Iteration: 94600 - cost: 0.26127 - accuracy: 0.88000
# Iteration: 94650 - cost: 0.26125 - accuracy: 0.88000
# Iteration: 94700 - cost: 0.26124 - accuracy: 0.88000
# Iteration: 94750 - cost: 0.26123 - accuracy: 0.88000
# Iteration: 94800 - cost: 0.26122 - accuracy: 0.88000
# Iteration: 94850 - cost: 0.26120 - accuracy: 0.88000
# Iteration: 94900 - cost: 0.26119 - accuracy: 0.88000
# Iteration: 94950 - cost: 0.26118 - accuracy: 0.88000
# Iteration: 95000 - cost: 0.26116 - accuracy: 0.88000
# Iteration: 95050 - cost: 0.26115 - accuracy: 0.88000
# Iteration: 95100 - cost: 0.26114 - accuracy: 0.88000
# Iteration: 95150 - cost: 0.26113 - accuracy: 0.88000
# Iteration: 95200 - cost: 0.26111 - accuracy: 0.88000
# Iteration: 95250 - cost: 0.26110 - accuracy: 0.88000
# Iteration: 95300 - cost: 0.26109 - accuracy: 0.88000
# Iteration: 95350 - cost: 0.26108 - accuracy: 0.88000
# Iteration: 95400 - cost: 0.26106 - accuracy: 0.88000
# Iteration: 95450 - cost: 0.26105 - accuracy: 0.88000
# Iteration: 95500 - cost: 0.26104 - accuracy: 0.88000
# Iteration: 95550 - cost: 0.26102 - accuracy: 0.88000
# Iteration: 95600 - cost: 0.26101 - accuracy: 0.88000
# Iteration: 95650 - cost: 0.26100 - accuracy: 0.88000
# Iteration: 95700 - cost: 0.26099 - accuracy: 0.88000
# Iteration: 95750 - cost: 0.26097 - accuracy: 0.88000
# Iteration: 95800 - cost: 0.26096 - accuracy: 0.88000
# Iteration: 95850 - cost: 0.26095 - accuracy: 0.88000
# Iteration: 95900 - cost: 0.26093 - accuracy: 0.88000
# Iteration: 95950 - cost: 0.26092 - accuracy: 0.88000
# Iteration: 96000 - cost: 0.26091 - accuracy: 0.88000
# Iteration: 96050 - cost: 0.26090 - accuracy: 0.88000
# Iteration: 96100 - cost: 0.26088 - accuracy: 0.88000
# Iteration: 96150 - cost: 0.26087 - accuracy: 0.88000
# Iteration: 96200 - cost: 0.26086 - accuracy: 0.88000
# Iteration: 96250 - cost: 0.26084 - accuracy: 0.88000
# Iteration: 96300 - cost: 0.26083 - accuracy: 0.88000
# Iteration: 96350 - cost: 0.26082 - accuracy: 0.88000
# Iteration: 96400 - cost: 0.26081 - accuracy: 0.88000
# Iteration: 96450 - cost: 0.26079 - accuracy: 0.88000
# Iteration: 96500 - cost: 0.26078 - accuracy: 0.88000
# Iteration: 96550 - cost: 0.26077 - accuracy: 0.88000
# Iteration: 96600 - cost: 0.26075 - accuracy: 0.88000
# Iteration: 96650 - cost: 0.26074 - accuracy: 0.88000
# Iteration: 96700 - cost: 0.26073 - accuracy: 0.88000
# Iteration: 96750 - cost: 0.26072 - accuracy: 0.88000
# Iteration: 96800 - cost: 0.26070 - accuracy: 0.88000
# Iteration: 96850 - cost: 0.26069 - accuracy: 0.88000
# Iteration: 96900 - cost: 0.26068 - accuracy: 0.88000
# Iteration: 96950 - cost: 0.26066 - accuracy: 0.88000
# Iteration: 97000 - cost: 0.26065 - accuracy: 0.88000
# Iteration: 97050 - cost: 0.26064 - accuracy: 0.88000
# Iteration: 97100 - cost: 0.26063 - accuracy: 0.88000
# Iteration: 97150 - cost: 0.26061 - accuracy: 0.88000
# Iteration: 97200 - cost: 0.26060 - accuracy: 0.88000
# Iteration: 97250 - cost: 0.26059 - accuracy: 0.88000
# Iteration: 97300 - cost: 0.26057 - accuracy: 0.88000
# Iteration: 97350 - cost: 0.26056 - accuracy: 0.88000
# Iteration: 97400 - cost: 0.26055 - accuracy: 0.88000
# Iteration: 97450 - cost: 0.26053 - accuracy: 0.88000
# Iteration: 97500 - cost: 0.26052 - accuracy: 0.88000
# Iteration: 97550 - cost: 0.26051 - accuracy: 0.88000
# Iteration: 97600 - cost: 0.26050 - accuracy: 0.88000
# Iteration: 97650 - cost: 0.26048 - accuracy: 0.88000
# Iteration: 97700 - cost: 0.26047 - accuracy: 0.88000
# Iteration: 97750 - cost: 0.26046 - accuracy: 0.88000
# Iteration: 97800 - cost: 0.26044 - accuracy: 0.88000
# Iteration: 97850 - cost: 0.26043 - accuracy: 0.88000
# Iteration: 97900 - cost: 0.26042 - accuracy: 0.88000
# Iteration: 97950 - cost: 0.26040 - accuracy: 0.88000
# Iteration: 98000 - cost: 0.26039 - accuracy: 0.88000
# Iteration: 98050 - cost: 0.26038 - accuracy: 0.88000
# Iteration: 98100 - cost: 0.26037 - accuracy: 0.88000
# Iteration: 98150 - cost: 0.26035 - accuracy: 0.88000
# Iteration: 98200 - cost: 0.26034 - accuracy: 0.88000
# Iteration: 98250 - cost: 0.26033 - accuracy: 0.88000
# Iteration: 98300 - cost: 0.26031 - accuracy: 0.88000
# Iteration: 98350 - cost: 0.26030 - accuracy: 0.88000
# Iteration: 98400 - cost: 0.26029 - accuracy: 0.88000
# Iteration: 98450 - cost: 0.26027 - accuracy: 0.88000
# Iteration: 98500 - cost: 0.26026 - accuracy: 0.88000
# Iteration: 98550 - cost: 0.26025 - accuracy: 0.88000
# Iteration: 98600 - cost: 0.26023 - accuracy: 0.88000
# Iteration: 98650 - cost: 0.26022 - accuracy: 0.88000
# Iteration: 98700 - cost: 0.26021 - accuracy: 0.88000
# Iteration: 98750 - cost: 0.26020 - accuracy: 0.88000
# Iteration: 98800 - cost: 0.26018 - accuracy: 0.88000
# Iteration: 98850 - cost: 0.26017 - accuracy: 0.88000
# Iteration: 98900 - cost: 0.26016 - accuracy: 0.88000
# Iteration: 98950 - cost: 0.26014 - accuracy: 0.88000
# Iteration: 99000 - cost: 0.26013 - accuracy: 0.88000
# Iteration: 99050 - cost: 0.26012 - accuracy: 0.88000
# Iteration: 99100 - cost: 0.26010 - accuracy: 0.88000
# Iteration: 99150 - cost: 0.26009 - accuracy: 0.88000
# Iteration: 99200 - cost: 0.26008 - accuracy: 0.88000
# Iteration: 99250 - cost: 0.26006 - accuracy: 0.88000
# Iteration: 99300 - cost: 0.26005 - accuracy: 0.88000
# Iteration: 99350 - cost: 0.26004 - accuracy: 0.88000
# Iteration: 99400 - cost: 0.26002 - accuracy: 0.88000
# Iteration: 99450 - cost: 0.26001 - accuracy: 0.88000
# Iteration: 99500 - cost: 0.26000 - accuracy: 0.88000
# Iteration: 99550 - cost: 0.25998 - accuracy: 0.88000
# Iteration: 99600 - cost: 0.25997 - accuracy: 0.88000
# Iteration: 99650 - cost: 0.25996 - accuracy: 0.88000
# Iteration: 99700 - cost: 0.25995 - accuracy: 0.88000
# Iteration: 99750 - cost: 0.25993 - accuracy: 0.88000
# Iteration: 99800 - cost: 0.25992 - accuracy: 0.88000
# Iteration: 99850 - cost: 0.25991 - accuracy: 0.88000
# Iteration: 99900 - cost: 0.25989 - accuracy: 0.88111
# Iteration: 99950 - cost: 0.25988 - accuracy: 0.88111

# %%
# Prediction
Y_test_hat, _ = full_forward_propagation(np.transpose(X_test), params_values, NN_ARCHITECTURE)

# %%
# Accuracy achieved on the test set
acc_test = get_accuracy_value(Y_test_hat, np.transpose(y_test.reshape((y_test.shape[0], 1))))
print("Test set accuracy: {:.2f} - David".format(acc_test))
# Out:
# Test set accuracy: 0.84 - David

# %% [markdown]
# ## Visualisation of the learning process

# %%
# boundary of the graph
GRID_X_START = -1.5
GRID_X_END = 2.5
GRID_Y_START = -1.0
GRID_Y_END = 2
# output directory (the folder must be created on the drive)
OUTPUT_DIR = "./binary_classification_vizualizations/"

# %%
grid = np.mgrid[GRID_X_START:GRID_X_END:100j,GRID_X_START:GRID_Y_END:100j]
grid_2d = grid.reshape(2, -1).T
XX, YY = grid

def callback_keras_plot(epoch, logs):
    plot_title = "Keras Model - It: {:05}".format(epoch)
    file_name = "keras_model_{:05}.png".format(epoch)
    file_path = os.path.join(OUTPUT_DIR, file_name)
    prediction_probs = model.predict_proba(grid_2d, batch_size=32, verbose=0)
    make_plot(X_test, y_test, plot_title, file_name=file_path, XX=XX, YY=YY, preds=prediction_probs)

# Adding callback functions that they will run in every epoch
testmodelcb = keras.callbacks.LambdaCallback(on_epoch_end=callback_keras_plot)

# Building a model
model = Sequential()
model.add(Dense(25, input_dim=2,activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(25, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# Training
history = model.fit(X_train, y_train, epochs=200, verbose=0, callbacks=[testmodelcb])

rediction_probs = model.predict_proba(grid_2d, batch_size=32, verbose=0)
make_plot(X_test, y_test, "Keras Model", file_name=None, XX=XX, YY=YY, preds=prediction_probs)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-670d47779f0d> in <module>
#      24
#      25 # Training
# ---> 26 history = model.fit(X_train, y_train, epochs=200, verbose=0, callbacks=[testmodelcb])
#      27
#      28 rediction_probs = model.predict_proba(grid_2d, batch_size=32, verbose=0)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1202           epoch_logs.update(val_logs)
#    1203
# -> 1204         callbacks.on_epoch_end(epoch, epoch_logs)
#    1205         training_logs = epoch_logs
#    1206         if self.stop_training:
#
# ~\anaconda3\lib\site-packages\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     412         if numpy_logs is None:  # Only convert once.
#     413           numpy_logs = tf_utils.sync_to_numpy_or_python_type(logs)
# --> 414         callback.on_epoch_end(epoch, numpy_logs)
#     415
#     416   def on_train_batch_begin(self, batch, logs=None):
#
# <ipython-input-60-670d47779f0d> in callback_keras_plot(epoch, logs)
#       8     file_path = os.path.join(OUTPUT_DIR, file_name)
#       9     prediction_probs = model.predict_proba(grid_2d, batch_size=32, verbose=0)
# ---> 10     make_plot(X_test, y_test, plot_title, file_name=file_path, XX=XX, YY=YY, preds=prediction_probs)
#      11
#      12 # Adding callback functions that they will run in every epoch
#
# <ipython-input-48-dee97eb9587a> in make_plot(X, y, plot_name, file_name, XX, YY, preds, dark)
#      25     plt.scatter(X[:, 0], X[:, 1], c=y.ravel(), s=40, cmap=plt.cm.Spectral, edgecolors='black')
#      26     if(file_name):
# ---> 27         plt.savefig(file_name)
#      28         plt.close()
#      29
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     508         """
#     509         FigureCanvasAgg.draw(self)
# --> 510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2097                 fp = builtins.open(filename, "r+b")
#    2098             else:
# -> 2099                 fp = builtins.open(filename, "w+b")
#    2100
#    2101         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: './binary_classification_vizualizations/keras_model_00000.png'

# %%
def callback_numpy_plot(index, params):
    plot_title = "NumPy Model - It: {:05}".format(index)
    file_name = "numpy_model_{:05}.png".format(index//50)
    file_path = os.path.join(OUTPUT_DIR, file_name)
    prediction_probs, _ = full_forward_propagation(np.transpose(grid_2d), params, NN_ARCHITECTURE)
    prediction_probs = prediction_probs.reshape(prediction_probs.shape[1], 1)
    make_plot(X_test, y_test, plot_title, file_name=file_path, XX=XX, YY=YY, preds=prediction_probs, dark=True)
    
# Training
params_values = train(np.transpose(X_train), np.transpose(y_train.reshape((y_train.shape[0], 1))), NN_ARCHITECTURE, 10000, 0.01, False, callback_numpy_plot)

# %%
prediction_probs_numpy, _ = full_forward_propagation(np.transpose(grid_2d), params_values, NN_ARCHITECTURE)
prediction_probs_numpy = prediction_probs_numpy.reshape(prediction_probs_numpy.shape[1], 1)
make_plot(X_test, y_test, "NumPy Model", file_name=None, XX=XX, YY=YY, preds=prediction_probs_numpy)
