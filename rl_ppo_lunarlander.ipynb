# %%
# PPO, https://spinningup.openai.com/en/latest/algorithms/ppo.html
# Pretty stable, but could be better

# %%
# %pylab inline
import random
import time
import numpy as np

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model, clone_model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.layers import Input, Dense, Activation, Lambda

import gym
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#env = gym.make("CartPole-v1")
env = gym.make("LunarLander-v2")
#env = gym.make("Pong-v0")
env.observation_space, env.action_space, type(env.action_space)
# Out:
# (Box(8,), Discrete(4), gym.spaces.discrete.Discrete)

# %%
# policy function
x =in_state = Input(env.observation_space.shape)
#state_in_tuple = (210*160*3,)
#x = in_state = Input(state_in_tuple)
x = Dense(32, activation='elu')(x)
x = Dense(32, activation='elu')(x)
x = Dense(32, activation='elu')(x)
x = Dense(env.action_space.n)(x)
action_dist = Lambda(lambda x: tf.nn.log_softmax(x, axis=-1))(x)
p = Model(in_state, action_dist)
pf = K.function(p.layers[0].input,
                [p.layers[-1].output,
                 tf.random.categorical(p.layers[-1].output, 1)[0]])

in_advantage = Input((1,))
in_old_prediction = Input((env.action_space.n,))
def loss(y_true, y_pred): 
  advantage = tf.reshape(in_advantage, (-1,))
  
  # y_pred is the log probs of the actions
  # y_true is the action mask
  prob = tf.reduce_sum(y_true * y_pred, axis=-1)
  old_prob = tf.reduce_sum(y_true * in_old_prediction, axis=-1)
  ratio = tf.exp(prob - old_prob)  # hehe, they are log probs, so we subtract
  
  # this is the VPG objective
  #ll = -(prob * advantage)
  
  # this is PPO objective
  ll = -K.minimum(ratio*advantage, K.clip(ratio, 0.8, 1.2)*advantage)
  return ll

popt = Model([in_state, in_advantage, in_old_prediction], action_dist)
popt.compile(Adam(5e-4), loss)
popt.summary()

# value function
x = in1 = Input(env.observation_space.shape)
x = Dense(32, activation='elu')(x)
x = Dense(32, activation='elu')(x)
x = Dense(32, activation='elu')(x)
x = Dense(1)(x)
v = Model(in1, x)
v.compile(Adam(1e-3), 'mse')
v.summary()

vf = K.function(v.layers[0].input, v.layers[-1].output)

gamma = 0.99
lll = []
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 8)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                288
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_7 (Dense)              (None, 4)                 132
# _________________________________________________________________
# lambda (Lambda)              (None, 4)                 0
# =================================================================
# Total params: 2,532
# Trainable params: 2,532
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 8)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                288
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 2,433
# Trainable params: 2,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.13.0-rc0

# %%
for epoch in range(100):
  st = time.perf_counter()
  
  X,Y,V,P = [],[],[],[]
  ll = []
  while len(X) < 8192:
    obs = env.reset()
    #print(obs.shape)
    #print(type(obs.reshape(1,-1)))
    #print(obs.reshape(1,-1).shape)
    #obs_ = obs.reshape(-1,1)
    #print(obs.shape)
    #print(obs_.shape)
    #obs_1 = np.ravel(obs_)
    #print(obs_1.shape)
    
    rews = []

    while True:
      # get the action
      #pred, act = [x[0] for x in pf(obs_1[None])]
      pred, act = [x[0] for x in pf(obs[None])]
      P.append(pred)
      
      # save this state action pair
      X.append(np.copy(obs))
      act_mask = np.zeros((env.action_space.n))
      act_mask[act] = 1.0
      Y.append(act_mask)

      # take the action and save the reward
      obs, rew, done, _ = env.step(act)
      rews.append(rew)

      if done:
        ll.append(np.sum(rews))
        # computes rewards to go with gamma discounting
        for i in range(len(rews)-2, -1, -1):
          rews[i] += rews[i+1] * gamma
        V.extend(rews)
        break
  X,Y,V,P = [np.array(x) for x in [X,Y,V,P]]

  # subtract value baseline to get advantage
  A = V - vf(X)[:, 0]
  
  loss = popt.fit([X,A,P],Y, batch_size=1024, epochs=10, shuffle=True, verbose=0)
  loss = loss.history['loss'][-1]
  vloss = v.fit(X, V, batch_size=1024, epochs=10, shuffle=True, verbose=0)
  vloss = vloss.history['loss'][-1]
        
  lll.append((epoch, np.mean(ll), loss, vloss, len(X), len(ll), time.perf_counter() - st))
  print("%3d  ep_rew:%9.2f  loss:%7.2f   vloss:%9.2f  counts: %5d/%3d tm: %.2f s" % lll[-1])
# Out:
#   0  ep_rew:   231.91  loss:   9.25   vloss:   876.87  counts:  8318/ 32 tm: 6.62 s
#   1  ep_rew:   259.55  loss:  -6.44   vloss:   725.20  counts:  8229/ 37 tm: 5.18 s
#   2  ep_rew:   228.41  loss:   3.63   vloss:  1047.12  counts:  8223/ 40 tm: 5.02 s
#   3  ep_rew:   238.34  loss:  -1.55   vloss:   630.29  counts:  8287/ 36 tm: 5.40 s
#   4  ep_rew:   272.10  loss:  -4.01   vloss:   360.61  counts:  8262/ 34 tm: 5.41 s
#   5  ep_rew:   244.67  loss:   8.25   vloss:   668.10  counts:  8397/ 40 tm: 5.15 s
#   6  ep_rew:   239.94  loss:  -3.42   vloss:   573.04  counts:  8367/ 44 tm: 5.03 s
#   7  ep_rew:   215.72  loss:   6.24   vloss:   968.86  counts:  8278/ 33 tm: 5.81 s
#   8  ep_rew:   249.41  loss:  -9.42   vloss:   402.06  counts:  8240/ 32 tm: 5.77 s
#   9  ep_rew:   259.32  loss:   5.83   vloss:   497.80  counts:  8347/ 36 tm: 5.19 s
#  10  ep_rew:   240.70  loss:   8.04   vloss:   672.94  counts:  8308/ 37 tm: 5.55 s
#  11  ep_rew:   259.53  loss:  -1.23   vloss:   624.63  counts:  8223/ 36 tm: 5.26 s
#  12  ep_rew:   253.41  loss:   1.14   vloss:   551.11  counts:  8232/ 38 tm: 5.12 s
#  13  ep_rew:   257.10  loss:   9.34   vloss:   488.42  counts:  8994/ 36 tm: 6.20 s
#  14  ep_rew:   245.75  loss:  -0.89   vloss:   786.80  counts:  8278/ 37 tm: 5.36 s
#  15  ep_rew:   268.53  loss:  -5.73   vloss:   328.35  counts:  8359/ 38 tm: 5.45 s
#  16  ep_rew:   262.62  loss:  -0.77   vloss:   313.67  counts:  8297/ 40 tm: 5.07 s
#  17  ep_rew:   260.99  loss:   4.05   vloss:   582.24  counts:  8326/ 37 tm: 5.36 s
#  18  ep_rew:   278.97  loss:  -3.31   vloss:   276.33  counts:  8548/ 37 tm: 5.37 s
#  19  ep_rew:   257.06  loss:   6.99   vloss:   497.53  counts:  8344/ 35 tm: 5.80 s
#  20  ep_rew:   265.22  loss:   4.76   vloss:   575.81  counts:  8203/ 31 tm: 5.49 s
#  21  ep_rew:   275.31  loss:  -3.49   vloss:   374.88  counts:  8261/ 39 tm: 5.01 s
#  22  ep_rew:   269.38  loss:  -1.43   vloss:   352.43  counts:  8378/ 41 tm: 4.99 s
#  23  ep_rew:   257.40  loss:   4.38   vloss:   676.24  counts:  8253/ 38 tm: 4.98 s
#  24  ep_rew:   258.21  loss:  -0.57   vloss:   451.60  counts:  8245/ 37 tm: 5.06 s
#  25  ep_rew:   244.90  loss:   1.20   vloss:   807.22  counts:  8339/ 39 tm: 5.30 s
#  26  ep_rew:   275.43  loss:  -2.92   vloss:   185.77  counts:  8301/ 35 tm: 5.23 s
#  27  ep_rew:   250.11  loss:   7.60   vloss:   517.42  counts:  8242/ 38 tm: 5.09 s
#  28  ep_rew:   242.39  loss:   3.03   vloss:   570.38  counts:  8276/ 40 tm: 4.95 s
#  29  ep_rew:   270.45  loss:  -4.31   vloss:   377.12  counts:  8233/ 37 tm: 5.22 s
#  30  ep_rew:   264.94  loss:   4.93   vloss:   322.86  counts:  8234/ 36 tm: 5.19 s
#  31  ep_rew:   281.29  loss:  -8.64   vloss:    96.93  counts:  8242/ 39 tm: 4.91 s
#  32  ep_rew:   267.59  loss:   2.81   vloss:   197.15  counts:  8211/ 39 tm: 4.96 s
#  33  ep_rew:   273.98  loss:  -2.07   vloss:   344.42  counts:  8277/ 39 tm: 5.06 s
#  34  ep_rew:   255.18  loss:   4.78   vloss:   689.83  counts:  8251/ 38 tm: 5.11 s
#  35  ep_rew:   268.59  loss:  -5.65   vloss:   440.35  counts:  8323/ 40 tm: 5.08 s
#  36  ep_rew:   245.60  loss:   8.69   vloss:   723.86  counts:  8486/ 40 tm: 5.46 s
#  37  ep_rew:   269.32  loss:  -6.29   vloss:   304.56  counts:  8357/ 39 tm: 5.08 s
#  38  ep_rew:   256.48  loss:   2.90   vloss:   571.64  counts:  8292/ 38 tm: 5.20 s
#  39  ep_rew:   259.78  loss:   0.27   vloss:   662.56  counts:  8193/ 39 tm: 5.02 s
#  40  ep_rew:   260.39  loss:   6.51   vloss:   554.24  counts:  8277/ 37 tm: 5.32 s
#  41  ep_rew:   275.19  loss:  -6.23   vloss:   154.79  counts:  8380/ 39 tm: 5.23 s
#  42  ep_rew:   267.34  loss:  -1.59   vloss:   291.69  counts:  8218/ 40 tm: 5.02 s
#  43  ep_rew:   256.39  loss:   5.97   vloss:   534.22  counts:  8257/ 36 tm: 5.43 s
#  44  ep_rew:   265.46  loss:   3.43   vloss:   519.79  counts:  8303/ 33 tm: 5.93 s
#  45  ep_rew:   269.84  loss:  -3.52   vloss:   324.06  counts:  8465/ 39 tm: 5.35 s
#  46  ep_rew:   281.50  loss:  -1.89   vloss:    77.21  counts:  8263/ 40 tm: 4.98 s
#  47  ep_rew:   257.56  loss:  14.10   vloss:   422.12  counts:  8790/ 37 tm: 5.77 s
#  48  ep_rew:   252.90  loss:  -0.33   vloss:   618.54  counts:  8257/ 36 tm: 5.67 s
#  49  ep_rew:   281.27  loss:  -3.22   vloss:   473.23  counts:  8265/ 38 tm: 5.37 s
#  50  ep_rew:   251.76  loss:   8.03   vloss:   330.56  counts:  8391/ 38 tm: 5.52 s
#  51  ep_rew:   254.80  loss:   1.57   vloss:   568.38  counts:  8304/ 41 tm: 5.53 s
#  52  ep_rew:   252.78  loss:  -1.15   vloss:   781.43  counts:  8213/ 42 tm: 4.86 s
#  53  ep_rew:   268.13  loss:  -6.31   vloss:   373.29  counts:  8371/ 41 tm: 5.18 s
#  54  ep_rew:   265.77  loss:  -1.55   vloss:   310.71  counts:  8233/ 41 tm: 5.14 s
#  55  ep_rew:   262.44  loss:   9.81   vloss:   591.23  counts:  8349/ 35 tm: 6.06 s
#  56  ep_rew:   269.18  loss:  -7.84   vloss:   286.02  counts:  8379/ 42 tm: 5.50 s
#  57  ep_rew:   285.36  loss:  -1.55   vloss:    75.55  counts:  8296/ 39 tm: 5.49 s
#  58  ep_rew:   275.06  loss:   1.74   vloss:   200.61  counts:  8286/ 40 tm: 5.75 s
#  59  ep_rew:   253.64  loss:   7.86   vloss:   542.38  counts:  8264/ 39 tm: 5.28 s
#  60  ep_rew:   251.86  loss:  -4.74   vloss:   811.28  counts:  8248/ 31 tm: 5.75 s
#  61  ep_rew:   246.20  loss:   4.70   vloss:   593.82  counts:  8871/ 39 tm: 5.94 s
#  62  ep_rew:   255.69  loss:   2.62   vloss:   696.81  counts:  8313/ 35 tm: 5.65 s
#  63  ep_rew:   249.47  loss:  -3.50   vloss:   590.68  counts:  8222/ 40 tm: 5.20 s
#  64  ep_rew:   265.86  loss:  -2.30   vloss:   258.42  counts:  8216/ 40 tm: 5.15 s
#  65  ep_rew:   262.56  loss:   1.82   vloss:   500.37  counts:  8273/ 40 tm: 5.23 s
#  66  ep_rew:   268.93  loss:  -0.67   vloss:   431.29  counts:  8373/ 40 tm: 5.38 s
#  67  ep_rew:   262.42  loss:   2.53   vloss:   582.69  counts:  8318/ 36 tm: 5.33 s
#  68  ep_rew:   259.20  loss:   3.66   vloss:   475.97  counts:  8337/ 41 tm: 4.86 s
#  69  ep_rew:   281.67  loss:  -3.82   vloss:   105.02  counts:  8313/ 40 tm: 4.85 s
#  70  ep_rew:   250.81  loss:   7.29   vloss:   569.39  counts:  8302/ 38 tm: 5.19 s
#  71  ep_rew:   262.94  loss:  -0.33   vloss:   263.32  counts:  8347/ 42 tm: 4.79 s
#  72  ep_rew:   274.95  loss:  -7.00   vloss:   131.96  counts:  8313/ 41 tm: 4.81 s
#  73  ep_rew:   274.68  loss:  -3.37   vloss:   221.96  counts:  8375/ 41 tm: 4.88 s
#  74  ep_rew:   219.77  loss:  14.60   vloss:   849.60  counts:  8312/ 42 tm: 5.32 s
#  75  ep_rew:   259.76  loss:  -6.63   vloss:   496.23  counts:  8206/ 42 tm: 5.05 s
#  76  ep_rew:   248.39  loss:   7.82   vloss:   723.48  counts:  8311/ 39 tm: 5.23 s
#  77  ep_rew:   253.09  loss:  -1.48   vloss:   505.56  counts:  8201/ 39 tm: 5.21 s
#  78  ep_rew:   248.81  loss:   4.42   vloss:   595.85  counts:  8288/ 38 tm: 6.34 s
#  79  ep_rew:   264.10  loss:  -2.26   vloss:   288.57  counts:  8373/ 41 tm: 5.59 s
#  80  ep_rew:   257.31  loss:   3.22   vloss:   466.67  counts:  8271/ 41 tm: 5.47 s
#  81  ep_rew:   246.62  loss:   1.76   vloss:   809.28  counts:  8338/ 37 tm: 6.27 s
#  82  ep_rew:   257.09  loss:  -0.92   vloss:   480.19  counts:  8294/ 39 tm: 5.74 s
#  83  ep_rew:   266.60  loss:  -5.71   vloss:   414.66  counts:  8228/ 42 tm: 5.29 s
#  84  ep_rew:   257.44  loss:   7.99   vloss:   646.87  counts:  8390/ 41 tm: 5.65 s
#  85  ep_rew:   275.83  loss:  -9.82   vloss:   304.54  counts:  8360/ 42 tm: 4.82 s
#  86  ep_rew:   270.75  loss:   0.71   vloss:   559.13  counts:  8294/ 37 tm: 5.07 s
#  87  ep_rew:   275.49  loss:  -1.99   vloss:   168.32  counts:  8413/ 42 tm: 4.84 s
#  88  ep_rew:   262.72  loss:   9.15   vloss:   336.34  counts:  8341/ 37 tm: 5.43 s
#  89  ep_rew:   265.04  loss:  -1.52   vloss:   335.55  counts:  8271/ 38 tm: 5.87 s
#  90  ep_rew:   267.27  loss:  -2.03   vloss:   477.32  counts:  8268/ 38 tm: 5.40 s
#  91  ep_rew:   271.54  loss:  -0.69   vloss:   408.24  counts:  8438/ 42 tm: 5.30 s
#  92  ep_rew:   257.01  loss:   9.55   vloss:   371.68  counts:  8375/ 35 tm: 5.92 s
#  93  ep_rew:   266.75  loss:  -7.46   vloss:   463.32  counts:  8226/ 42 tm: 5.05 s
#  94  ep_rew:   266.23  loss:   2.37   vloss:   383.87  counts:  8483/ 40 tm: 5.49 s
#  95  ep_rew:   263.37  loss:  -0.88   vloss:   324.09  counts:  8262/ 41 tm: 5.50 s
#  96  ep_rew:   276.44  loss:  -2.97   vloss:    70.43  counts:  8245/ 40 tm: 5.39 s
#  97  ep_rew:   273.26  loss:  -1.03   vloss:   232.40  counts:  8234/ 40 tm: 5.12 s
#  98  ep_rew:   272.35  loss:   1.38   vloss:   223.43  counts:  8330/ 41 tm: 5.15 s
#  99  ep_rew:   263.25  loss:   7.35   vloss:   381.81  counts:  8230/ 34 tm: 5.77 s

# %%
figsize(16,8)
plt.subplot(1,2,1)
plot([x[1] for x in lll], label="Mean Episode Reward")
plot([x[2] for x in lll], label="Epoch Loss")
plt.legend()
plt.subplot(1,2,2)
plot([x[3] for x in lll], color='green', label="value Loss")
plt.legend()

# %%
obs = env.reset()
rews = []
while True:
  env.render()
  pred, act = [x[0] for x in pf(obs[None])]
  obs, rew, done, _ = env.step(np.argmax(pred))
  rews.append(rew)
  time.sleep(0.05)
  if done:
    break
print("ran %d steps, got %f reward" % (len(rews), np.sum(rews)))
# Out:
# ran 208 steps, got 289.944525 reward
